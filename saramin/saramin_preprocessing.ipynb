# %%
import pandas as pd

df = pd.read_csv('saramin_jobs.csv')
df.head()
# Out:
#             회사                                 제목  \
# 0   (주)딜리버드코리아  [딜리버드코리아] 데이터 분석가 / 데이터 사이언티스트 모집
# 1    (주)한국정보통계             [통계팀] 데이터 분석가(사회조사분석사)
# 2  스텝업파트너스주식회사             [글로벌 모바일게임 기업] 데이터 분석가
# 3   (주)엔엠에스컨설팅             CRM/데이터 분석가 (대형 가전마트사)
# 4     (주)데이터누리             [데이터누리] 데이터 분석가를 모십니다.
#
#                                                  URL       경력 계약형태  지역  \
# 0  https://www.saramin.co.kr/zf_user/jobs/relay/v...       경력  정규직  서울
# 1  https://www.saramin.co.kr/zf_user/jobs/relay/v...     경력무관  정규직  전북
# 2  https://www.saramin.co.kr/zf_user/jobs/relay/v...  경력 2~5년  정규직  서울
# 3  https://www.saramin.co.kr/zf_user/jobs/relay/v...    경력3년↑  정규직  서울
# 4  https://www.saramin.co.kr/zf_user/jobs/relay/v...    경력5년↑  정규직  서울
#
#      지역(구)       직무
# 0      강서구  데이터 분석가
# 1  전주시 완산구  데이터 분석가
# 2      강남구  데이터 분석가
# 3      송파구  데이터 분석가
# 4      강서구  데이터 분석가

# %%
df['직무'].value_counts()
# Out:
# 직무
# 데이터 분석가       200
# 데이터 엔지니어      200
# AI 개발자        200
# 클라우드 엔지니어     200
# API 개발자       200
# 머신러닝 엔지니어     200
# 데이터 사이언티스트    200
# 챗봇 개발자         98
# Name: count, dtype: int64

# %%
df.columns
# Out:
# Index(['회사', '제목', 'URL', '경력', '계약형태', '지역', '지역(구)', '직무'], dtype='object')

# %%
df['계약형태'].unique()
# Out:
# array(['정규직', '정규직·계약직', '계약직·인턴직', '파트·무기계약직', '무기계약직·계약직', '기간제·계약직',
#        '계약직', '정규직·전문연구요원', '정규직·인턴직', '위촉직', '교육생·기간제', '계약직·위촉직', nan,
#        '정규직·프리랜서', '정규직·기간제', '정규직·병역특례', '산업기능요원·현역', '교육생', '파트·프리랜서',
#        '전문연구요원·현역', '정규직·무기계약직', '인턴직', '계약직·파견직', '정규직·아르바이트', '프리랜서',
#        '정규직·파트'], dtype=object)

# %%
job_type = ['정규직', '인턴직', '계약직', '정규직·계약직', '정규직·인턴직',
       '정규직·기간제', '기간제·계약직', '정규직·프리랜서', '계약직·인턴직', '정규직·해외취업',
        '파트·프리랜서', '무기계약직·계약직', '프리랜서', '계약직·프리랜서', '정규직·무기계약직']

# %%
df_type = df[df['계약형태'].str.contains('|'.join(job_type), na=False)]
df_type[20:25]
# Out:
#             회사                                 제목  \
# 20  서울특별시보라매병원   보라매병원 데이터사이언스센터 데이터 분석 담당 연구원 모집
# 21     (주)네오위즈    [네오위즈] AI 연구원 - 데이터 분석 (전문연구요원)
# 22  서울특별시보라매병원     보라매병원 데이터사이언스센터 의학용어 분석 연구원 모집
# 23   에이치알포유(주)   [국내 리서치 업계 선도기업] 마케팅 리서치 (2~10년)
# 24  (주)케이스탯리서치  [케이스탯리서치] 2025년 연구원(신입, 경력) 공개 채용
#
#                                                   URL        경력      계약형태  지역  \
# 20  https://www.saramin.co.kr/zf_user/jobs/relay/v...      경력무관   계약직·인턴직  서울
# 21  https://www.saramin.co.kr/zf_user/jobs/relay/v...     경력3년↑       정규직  경기
# 22  https://www.saramin.co.kr/zf_user/jobs/relay/v...  경력 1~10년  파트·무기계약직  서울
# 23  https://www.saramin.co.kr/zf_user/jobs/relay/v...  경력 2~10년       정규직  서울
# 24  https://www.saramin.co.kr/zf_user/jobs/relay/v...      경력무관       정규직  서울
#
#       지역(구)       직무
# 20      동작구  데이터 분석가
# 21  성남시 분당구  데이터 분석가
# 22      동작구  데이터 분석가
# 23      금천구  데이터 분석가
# 24      서초구  데이터 분석가

# %%
df_type['계약형태'].unique()
# Out:
# array(['정규직', '정규직·계약직', '계약직·인턴직', '파트·무기계약직', '무기계약직·계약직', '기간제·계약직',
#        '계약직', '정규직·전문연구요원', '정규직·인턴직', '계약직·위촉직', '정규직·프리랜서', '정규직·기간제',
#        '정규직·병역특례', '파트·프리랜서', '정규직·무기계약직', '인턴직', '계약직·파견직', '정규직·아르바이트',
#        '프리랜서', '정규직·파트'], dtype=object)

# %%
df_type['직무'].value_counts()
# Out:
# 직무
# 클라우드 엔지니어     200
# API 개발자       200
# 데이터 사이언티스트    199
# 데이터 분석가       198
# AI 개발자        197
# 머신러닝 엔지니어     197
# 데이터 엔지니어      194
# 챗봇 개발자         91
# Name: count, dtype: int64

# %%
df_lower = df_type.copy()

df_lower['제목'] = df_lower['제목'].str.lower()

# %%
def check_keywords(row, keywords):
    for keyword_group in keywords:
        if all(keyword in row for keyword in keyword_group):
            return True
    return False

# %%
da_with = [
    ['데이터', '분석'],
    ['데이터', '분석가'],     
    ['data', 'analyst'],  
    ['db', '분석'],      
    ['데이터', '애널리스트'],
    ['buisness', 'analyst'],
    ['analyst'],   
    ['분석'],     
    ['데이터 분석'], 
    ['data analyst'] 
]

# %%
filt = df_lower[df_lower['직무'] == '데이터 분석가']

da = filt[filt['제목'].apply(lambda x: check_keywords(x, da_with))]
da.head()
# Out:
#             회사                                 제목  \
# 0   (주)딜리버드코리아  [딜리버드코리아] 데이터 분석가 / 데이터 사이언티스트 모집
# 1    (주)한국정보통계             [통계팀] 데이터 분석가(사회조사분석사)
# 2  스텝업파트너스주식회사             [글로벌 모바일게임 기업] 데이터 분석가
# 3   (주)엔엠에스컨설팅             crm/데이터 분석가 (대형 가전마트사)
# 4     (주)데이터누리             [데이터누리] 데이터 분석가를 모십니다.
#
#                                                  URL       경력 계약형태  지역  \
# 0  https://www.saramin.co.kr/zf_user/jobs/relay/v...       경력  정규직  서울
# 1  https://www.saramin.co.kr/zf_user/jobs/relay/v...     경력무관  정규직  전북
# 2  https://www.saramin.co.kr/zf_user/jobs/relay/v...  경력 2~5년  정규직  서울
# 3  https://www.saramin.co.kr/zf_user/jobs/relay/v...    경력3년↑  정규직  서울
# 4  https://www.saramin.co.kr/zf_user/jobs/relay/v...    경력5년↑  정규직  서울
#
#      지역(구)       직무
# 0      강서구  데이터 분석가
# 1  전주시 완산구  데이터 분석가
# 2      강남구  데이터 분석가
# 3      송파구  데이터 분석가
# 4      강서구  데이터 분석가

# %%
de_with = [
    ['데이터', '엔지니어'],    
    ['data', 'engineer'],  
    ['db', '엔지니어'],      
    ['db', 'engineer']
]

# %%
filt = df_lower[df_lower['직무'] == '데이터 엔지니어']

de = filt[filt['제목'].apply(lambda x: check_keywords(x, de_with))]
de.head()
# Out:
#               회사                                   제목  \
# 200    (주)카카오스타일                             데이터 엔지니어
# 201     (주)오픈베이스                          데이터 엔지니어 채용
# 202  (주)클라우드네트웍스  [클라우드네트웍스] 빅데이터 솔루션 엔지니어 모집 (신입/경력)
# 203     (주)에스티로직                          데이터 엔지니어 채용
# 204       (주)유클릭       [데이터 클라우드 플랫폼 개발자 채용] 데이터엔지니어
#
#                                                    URL        경력 계약형태  지역  \
# 200  https://www.saramin.co.kr/zf_user/jobs/relay/v...     경력5년↑  정규직  경기
# 201  https://www.saramin.co.kr/zf_user/jobs/relay/v...  경력 3~10년  정규직  서울
# 202  https://www.saramin.co.kr/zf_user/jobs/relay/v...      경력무관  정규직  서울
# 203  https://www.saramin.co.kr/zf_user/jobs/relay/v...     경력5년↑  정규직  서울
# 204  https://www.saramin.co.kr/zf_user/jobs/relay/v...     경력3년↑  정규직  경기
#
#        지역(구)        직무
# 200  성남시 분당구  데이터 엔지니어
# 201      서초구  데이터 엔지니어
# 202      강남구  데이터 엔지니어
# 203      송파구  데이터 엔지니어
# 204      과천시  데이터 엔지니어

# %%
ai_with = [
    ['a', 'i', '개발'],
    ['인공지능', '개발'],
    ['a', 'i', '엔지니어'],
    ['a', 'i', 'engineer'],
    ['a', 'i', '연구'],
    ['a', 'i', 'architect'],
    ['딥', '러닝'],
    ['deep', 'learning'],
    ['machine', 'learning'],
    ['a', 'i', 'researcher'],
    ['a', 'i', 'solution'], 
    ['a', 'i', '전문가']
]

# %%
filt = df_lower[df_lower['직무'] == 'AI 개발자']

ai = filt[filt['제목'].apply(lambda x: check_keywords(x, ai_with))]
ai.head()
# Out:
#              회사                                                제목  \
# 400     (주)애니로직  [(주)애니로직] (경력3~15년) 웹/ai 개발자 - java/vue/react/py
# 401     (주)디비엔텍       [병역특례 우대] ai(딥러닝)기반 object detection 개발자 모집
# 402       (주)헥토                      [헥토] cube ai랩 ai개발팀 개발자 (경력)
# 403    제이씨현시스템㈜                     제이씨현시스템(주) ai연구소 ai솔루션 개발자 모집
# 404  (주)엔티엘헬스케어                   [병역특례 우대] (주)엔티엘헬스케어 ai 개발자 연구원
#
#                                                    URL        경력     계약형태  지역  \
# 400  https://www.saramin.co.kr/zf_user/jobs/relay/v...  경력 3~15년  정규직·인턴직  서울
# 401  https://www.saramin.co.kr/zf_user/jobs/relay/v...      경력무관      정규직  인천
# 402  https://www.saramin.co.kr/zf_user/jobs/relay/v...     경력7년↑      정규직  서울
# 403  https://www.saramin.co.kr/zf_user/jobs/relay/v...      경력무관      정규직  서울
# 404  https://www.saramin.co.kr/zf_user/jobs/relay/v...     신입·경력      정규직  경기
#
#        지역(구)      직무
# 400      금천구  AI 개발자
# 401       서구  AI 개발자
# 402      강남구  AI 개발자
# 403      용산구  AI 개발자
# 404  성남시 수정구  AI 개발자

# %%
cb_with = [
    ['챗봇', '개발'],
    ['a', 'i', '개발'],
    ['llm', '개발'],
    ['react', '개발'], 
    ['프론트', '개발']
]

# %%
filt = df_lower[df_lower['직무'] == '챗봇 개발자']

cb = filt[filt['제목'].apply(lambda x: check_keywords(x, cb_with))]
cb.head()
# Out:
#             회사                                     제목  \
# 600    (주)메이크봇                  ai챗봇 선두기업, php웹개발자 채용
# 601      (주)쿨스   [ict사업부] 프론트/백엔드/챗봇/인공지능 웹개발자 정규직 채용
# 602  (주)에이아이세스        [aicess] ai 개발자 (지식기반 ai 챗봇) 채용
# 603     비즈톡(주)                  카카오톡 상담톡 및 챗봇 서비스 개발자
# 607   (주)인티그리트  [지능형 로보틱스 플랫폼] ai 플랫폼,디바이스s/w, 펌웨어 개발
#
#                                                    URL        경력     계약형태  지역  \
# 600  https://www.saramin.co.kr/zf_user/jobs/relay/v...      경력무관  정규직·계약직  서울
# 601  https://www.saramin.co.kr/zf_user/jobs/relay/v...      경력무관      정규직  부산
# 602  https://www.saramin.co.kr/zf_user/jobs/relay/v...     경력3년↑      정규직  서울
# 603  https://www.saramin.co.kr/zf_user/jobs/relay/v...  경력 5~10년      정규직  서울
# 607  https://www.saramin.co.kr/zf_user/jobs/relay/v...      경력무관      정규직  서울
#
#     지역(구)      직무
# 600   구로구  챗봇 개발자
# 601   강서구  챗봇 개발자
# 602    중구  챗봇 개발자
# 603   강남구  챗봇 개발자
# 607   강남구  챗봇 개발자

# %%
cld_with = [
    ['클라우드', '엔지니어'],
    ['cloud', 'engineer'],
    ['cloud', '엔지니어'],
    ['클라우드', 'engineer'],
    ['cloud', 'architect'],
    ['클라우드', '아키텍트'],
    ['클라우드', '운영'],
    ['시스템', '엔지니어'],
    ['클라우드', '개발'],
    ['cloud', '개발'],
    ['서버', '엔지니어'],
    ['네트워크', '엔지니어'],
    ['network', '엔지니어'],
    ['네트워크', 'engineer'],
    ['인프라', '엔지니어'],
    ['cloud', 'sa']
]

# %%
filt = df_lower[df_lower['직무'] == '클라우드 엔지니어']

cld = filt[filt['제목'].apply(lambda x: check_keywords(x, cld_with))]
cld.head()
# Out:
#            회사                           제목  \
# 698  (주)카카오페이              인프라 - 클라우드 엔지니어
# 699  (주)빗썸코리아        클라우드엔지니어 - aws 서비스 운영
# 700  (주)파이오링크  [(주)파이오링크] 클라우드 시스템 엔지니어 채용
# 701  (주)빗썸코리아        클라우드엔지니어 - aws 서비스 운영
# 702   (주)엔큐브랩             클라우드 보안엔지니어 모집공고
#
#                                                    URL        경력 계약형태  지역  \
# 698  https://www.saramin.co.kr/zf_user/jobs/relay/v...        경력  정규직  경기
# 699  https://www.saramin.co.kr/zf_user/jobs/relay/v...  경력 5~10년  정규직  서울
# 700  https://www.saramin.co.kr/zf_user/jobs/relay/v...     경력2년↑  정규직  서울
# 701  https://www.saramin.co.kr/zf_user/jobs/relay/v...  경력 5~10년  정규직  서울
# 702  https://www.saramin.co.kr/zf_user/jobs/relay/v...      경력무관  정규직  경기
#
#        지역(구)         직무
# 698  성남시 분당구  클라우드 엔지니어
# 699      강남구  클라우드 엔지니어
# 700      금천구  클라우드 엔지니어
# 701      강남구  클라우드 엔지니어
# 702  성남시 수정구  클라우드 엔지니어

# %%
api_with = [
    ['개발']
]

# %%
filt = df_lower[df_lower['직무'] == 'API 개발자']

api = filt[filt['제목'].apply(lambda x: check_keywords(x, api_with))]
api.head()
# Out:
#                         회사                                             제목  \
# 898               (주)파이오링크  [코스닥 상장사] linux,python,java,api 개발자 모집(신입/경력)
# 899              (주)인피니소프트          [강소기업] 이노페이 pg시스템 및 전자금융/전자결제 api 개발자
# 900  주식회사 팬브릿지 (Fanbridge)                     [api] 웹 서비스 백엔드 개발자 채용(경력)
# 901               (주)맥크리오트            iot sw개발자 (rest api, linux, 모뎀) 모집건
# 902           (주)창소프트아이앤아이         창소프트아이앤아이 revit api pulgin 개발자 채용(경력직)
#
#                                                    URL        경력 계약형태  지역  \
# 898  https://www.saramin.co.kr/zf_user/jobs/relay/v...     신입·경력  정규직  서울
# 899  https://www.saramin.co.kr/zf_user/jobs/relay/v...     경력2년↑  정규직  서울
# 900  https://www.saramin.co.kr/zf_user/jobs/relay/v...     경력2년↑  정규직  서울
# 901  https://www.saramin.co.kr/zf_user/jobs/relay/v...  경력 2~15년  정규직  경기
# 902  https://www.saramin.co.kr/zf_user/jobs/relay/v...     경력2년↑  정규직  서울
#
#        지역(구)       직무
# 898      금천구  API 개발자
# 899      금천구  API 개발자
# 900      강남구  API 개발자
# 901  용인시 기흥구  API 개발자
# 902      강남구  API 개발자

# %%
ml_with = [
    ['머신', '러닝', '엔지니어'],
    ['machine', 'learning', 'engineer'],
    ['ml', 'engineer'],
    ['머신', '러닝', 'engineer'],
    ['ml', '엔지니어'],
    ['machine', 'learning', '엔지니어'],
    ['머신', '러닝', '개발'],
    ['ml', '개발'],
    ['machine', 'learning', '개발'],
    ['a', 'i', '개발']
]

# %%
filt = df_lower[df_lower['직무'] == '머신러닝 엔지니어']

ml = filt[filt['제목'].apply(lambda x: check_keywords(x, ml_with))]
ml.head()
# Out:
#                  회사                                   제목  \
# 1098      (주)이스트소프트  [estsoft] 음성 인식(stt) 머신러닝 엔지니어 (경력)
# 1099      (주)이스트소프트         [estsoft] llm 머신러닝 엔지니어 (경력)
# 1100    (주)딥브레인에이아이                        머신러닝/딥러닝 엔지니어
# 1101         이스트소프트  [estsoft] 음성 인식(stt) 머신러닝 엔지니어 (경력)
# 1102  (주)제이씨에프테크놀러지                         머신러닝 엔지니어 채용
#
#                                                     URL        경력 계약형태  지역  \
# 1098  https://www.saramin.co.kr/zf_user/jobs/relay/v...   경력 3~7년  정규직  서울
# 1099  https://www.saramin.co.kr/zf_user/jobs/relay/v...   경력 3~7년  정규직  서울
# 1100  https://www.saramin.co.kr/zf_user/jobs/relay/v...  경력 3~20년  정규직  서울
# 1101  https://www.saramin.co.kr/zf_user/jobs/relay/v...     경력3년↑  정규직  서울
# 1102  https://www.saramin.co.kr/zf_user/jobs/relay/v...   경력 3~8년  정규직  서울
#
#      지역(구)         직무
# 1098   서초구  머신러닝 엔지니어
# 1099   서초구  머신러닝 엔지니어
# 1100   강남구  머신러닝 엔지니어
# 1101   서초구  머신러닝 엔지니어
# 1102   금천구  머신러닝 엔지니어

# %%
ds_with = [
    ['데이터', '사이언티스트'],
    ['data', 'scientist']
]

# %%
filt = df_lower[df_lower['직무'] == '데이터 사이언티스트']

ds = filt[filt['제목'].apply(lambda x: check_keywords(x, ds_with))]
df.head()
# Out:
#             회사                                 제목  \
# 0   (주)딜리버드코리아  [딜리버드코리아] 데이터 분석가 / 데이터 사이언티스트 모집
# 1    (주)한국정보통계             [통계팀] 데이터 분석가(사회조사분석사)
# 2  스텝업파트너스주식회사             [글로벌 모바일게임 기업] 데이터 분석가
# 3   (주)엔엠에스컨설팅             CRM/데이터 분석가 (대형 가전마트사)
# 4     (주)데이터누리             [데이터누리] 데이터 분석가를 모십니다.
#
#                                                  URL       경력 계약형태  지역  \
# 0  https://www.saramin.co.kr/zf_user/jobs/relay/v...       경력  정규직  서울
# 1  https://www.saramin.co.kr/zf_user/jobs/relay/v...     경력무관  정규직  전북
# 2  https://www.saramin.co.kr/zf_user/jobs/relay/v...  경력 2~5년  정규직  서울
# 3  https://www.saramin.co.kr/zf_user/jobs/relay/v...    경력3년↑  정규직  서울
# 4  https://www.saramin.co.kr/zf_user/jobs/relay/v...    경력5년↑  정규직  서울
#
#      지역(구)       직무
# 0      강서구  데이터 분석가
# 1  전주시 완산구  데이터 분석가
# 2      강남구  데이터 분석가
# 3      송파구  데이터 분석가
# 4      강서구  데이터 분석가

# %%
final = pd.concat([da, de, ai, cb, cld, api, ml, ds], axis=0, ignore_index=True)
final.head()
# Out:
#             회사                                 제목  \
# 0   (주)딜리버드코리아  [딜리버드코리아] 데이터 분석가 / 데이터 사이언티스트 모집
# 1    (주)한국정보통계             [통계팀] 데이터 분석가(사회조사분석사)
# 2  스텝업파트너스주식회사             [글로벌 모바일게임 기업] 데이터 분석가
# 3   (주)엔엠에스컨설팅             crm/데이터 분석가 (대형 가전마트사)
# 4     (주)데이터누리             [데이터누리] 데이터 분석가를 모십니다.
#
#                                                  URL       경력 계약형태  지역  \
# 0  https://www.saramin.co.kr/zf_user/jobs/relay/v...       경력  정규직  서울
# 1  https://www.saramin.co.kr/zf_user/jobs/relay/v...     경력무관  정규직  전북
# 2  https://www.saramin.co.kr/zf_user/jobs/relay/v...  경력 2~5년  정규직  서울
# 3  https://www.saramin.co.kr/zf_user/jobs/relay/v...    경력3년↑  정규직  서울
# 4  https://www.saramin.co.kr/zf_user/jobs/relay/v...    경력5년↑  정규직  서울
#
#      지역(구)       직무
# 0      강서구  데이터 분석가
# 1  전주시 완산구  데이터 분석가
# 2      강남구  데이터 분석가
# 3      송파구  데이터 분석가
# 4      강서구  데이터 분석가

# %%
len(final)
# Out:
# 876

# %%
final['직무'].value_counts()
# Out:
# 직무
# AI 개발자        197
# API 개발자       166
# 클라우드 엔지니어     142
# 데이터 엔지니어      100
# 데이터 사이언티스트     83
# 머신러닝 엔지니어      74
# 데이터 분석가        64
# 챗봇 개발자         50
# Name: count, dtype: int64

# %%
import os

# %%
# 데이터 CSV 저장
output_file = 'saramin_jobs.csv'

# 파일이 이미 존재하면 삭제
if os.path.exists(output_file):
    os.remove(output_file)
    print(f"기존 파일 삭제 완료: {output_file}")

# 새로운 데이터 저장
df = pd.DataFrame(final)
df.to_csv(output_file, index=False, encoding='utf-8-sig')

print(f"CSV 저장 완료: {output_file}")
# Out:
# 기존 파일 삭제 완료: saramin_jobs.csv
# CSV 저장 완료: saramin_jobs.csv
