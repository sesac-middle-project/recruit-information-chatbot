# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
with open('../jobs.txt') as f:
    file = f.read()

print(file[:300])
# Out:
# 회사이름: ㈜인라이플, 공고이름: [주4.5일근무] 데이터 분석 및 기획자 채용, url: https://www.jobkorea.co.kr/Recruit/GI_Read/45711948?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D&listno=1, 경력: 경력2년↑, 지역: 서울, 직무: 데이터 분석
# 회사이름: 패스트파이브㈜, 공고이름: 데이터 분석 담당자, url: https://www.jobkorea.co.kr/Recruit/GI_Read

# %%
chfile = file.replace('\n', '\n\n')
chfile[:300]
# Out:
# '회사이름: ㈜인라이플, 공고이름: [주4.5일근무] 데이터 분석 및 기획자 채용, url: https://www.jobkorea.co.kr/Recruit/GI_Read/45711948?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D&listno=1, 경력: 경력2년↑, 지역: 서울, 직무: 데이터 분석\n\n회사이름: 패스트파이브㈜, 공고이름: 데이터 분석 담당자, url: https://www.jobkorea.co.kr/Recruit/GI_Rea'

# %%
from langchain_text_splitters import CharacterTextSplitter

splitter = CharacterTextSplitter.from_tiktoken_encoder(
    chunk_size = 400
)

lines = splitter.split_text(chfile)

# %%
lines[:5]
# Out:
# ['회사이름: ㈜인라이플, 공고이름: [주4.5일근무] 데이터 분석 및 기획자 채용, url: https://www.jobkorea.co.kr/Recruit/GI_Read/45711948?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D&listno=1, 경력: 경력2년↑, 지역: 서울, 직무: 데이터 분석',
#  '회사이름: 패스트파이브㈜, 공고이름: 데이터 분석 담당자, url: https://www.jobkorea.co.kr/Recruit/GI_Read/46017897?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D&listno=2, 경력: 경력5년↑, 지역: 서울, 직무: 데이터 분석',
#  '회사이름: 주식회사 빗썸, 공고이름: [빗썸] 비즈니스 데이터 분석, url: https://www.jobkorea.co.kr/Recruit/GI_Read/45906918?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D&listno=3, 경력: 경력7년↑, 지역: 서울, 직무: 데이터 분석',
#  '회사이름: ㈜컬리, 공고이름: [컬리] 온사이트 프로모션 데이터 분석, url: https://www.jobkorea.co.kr/Recruit/GI_Read/46002356?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D&listno=4, 경력: 경력, 지역: 서울, 직무: 데이터 분석',
#  '회사이름: ㈜숲(SOOP CO., LTD.), 공고이름: [soop] 데이터 분석 및 지표 설계, url: https://www.jobkorea.co.kr/Recruit/GI_Read/46006567?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D&listno=5, 경력: 경력3년↑, 지역: 경기, 직무: 데이터 분석']

# %%
from langchain_openai import OpenAIEmbeddings

embeddings = OpenAIEmbeddings(model='text-embedding-3-small')

# %%
from langchain_community.vectorstores import FAISS

db = FAISS.from_texts(texts=lines, embedding=embeddings)

# %%
db.docstore._dict
# Out:
# {'9b5a34fb-1add-4837-8ea7-16a96aec82a9': Document(page_content='회사이름: ㈜인라이플, 공고이름: [주4.5일근무] 데이터 분석 및 기획자 채용, url: https://www.jobkorea.co.kr/Recruit/GI_Read/45711948?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D&listno=1, 경력: 경력2년↑, 지역: 서울, 직무: 데이터 분석'),
#  '9d899baf-fbff-4687-aa26-c0660c13c929': Document(page_content='회사이름: 패스트파이브㈜, 공고이름: 데이터 분석 담당자, url: https://www.jobkorea.co.kr/Recruit/GI_Read/46017897?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D&listno=2, 경력: 경력5년↑, 지역: 서울, 직무: 데이터 분석'),
#  '296d0e2f-40a1-4b68-9718-b07c8283193c': Document(page_content='회사이름: 주식회사 빗썸, 공고이름: [빗썸] 비즈니스 데이터 분석, url: https://www.jobkorea.co.kr/Recruit/GI_Read/45906918?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D&listno=3, 경력: 경력7년↑, 지역: 서울, 직무: 데이터 분석'),
#  '07c148af-50e0-42e3-b76f-4433df1c5ce4': Document(page_content='회사이름: ㈜컬리, 공고이름: [컬리] 온사이트 프로모션 데이터 분석, url: https://www.jobkorea.co.kr/Recruit/GI_Read/46002356?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D&listno=4, 경력: 경력, 지역: 서울, 직무: 데이터 분석'),
#  '1570b02b-0015-4fc0-8520-12588c0a86f6': Document(page_content='회사이름: ㈜숲(SOOP CO., LTD.), 공고이름: [soop] 데이터 분석 및 지표 설계, url: https://www.jobkorea.co.kr/Recruit/GI_Read/46006567?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D&listno=5, 경력: 경력3년↑, 지역: 경기, 직무: 데이터 분석'),
#  'e0222845-4981-4abe-a746-5a80b93906e4': Document(page_content='회사이름: ㈜테크랩스, 공고이름: 마케팅 데이터 분석, url: https://www.jobkorea.co.kr/Recruit/GI_Read/45978816?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D&listno=6, 경력: 경력2년↑, 지역: 서울, 직무: 데이터 분석'),
#  '6d58be90-7bb5-4e40-afb3-07f31b3ca634': Document(page_content='회사이름: 콘센트릭스서비스코리아(유), 공고이름: ga/aa 데이터 분석, url: https://www.jobkorea.co.kr/Recruit/GI_Read/46028449?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D&listno=7, 경력: 경력1년↑, 지역: 서울, 직무: 데이터 분석'),
#  'b79e5afe-a949-4825-a142-0d896b5beb15': Document(page_content='회사이름: ㈜넥슨, 공고이름: [사업개발그룹] 데이터 분석 매니저, url: https://www.jobkorea.co.kr/Recruit/GI_Read/45711064?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D&listno=8, 경력: 경력3년↑, 지역: 경기, 직무: 데이터 분석'),
#  'e4ad7c43-0969-4fec-a9c6-aa7a5d3051cf': Document(page_content='회사이름: 주식회사 빗썸, 공고이름: [빗썸] 고객 데이터 분석 담당자, url: https://www.jobkorea.co.kr/Recruit/GI_Read/45799996?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D&listno=9, 경력: 경력3년↑, 지역: 서울, 직무: 데이터 분석'),
#  'f4bda96c-0352-4c98-a6c4-3b00258628be': Document(page_content='회사이름: 트리플하이엠, 공고이름: [연구소] 온라인 마케팅 데이터 분석 및 설계 (경력), url: https://www.jobkorea.co.kr/Recruit/GI_Read/45990899?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D&listno=10, 경력: 경력2년↑, 지역: 서울, 직무: 데이터 분석'),
#  '051f4fb8-5a81-41f9-a23b-eddb0212fd46': Document(page_content='회사이름: 쿠팡 주식회사, 공고이름: [쿠팡] 데이터 분석 pm (taxonomy), url: https://www.jobkorea.co.kr/Recruit/GI_Read/45921791?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D&listno=11, 경력: 경력3년↑, 지역: 서울, 직무: 데이터 분석'),
#  'a401e37a-fdb1-41ef-b38e-3b8c83b52e90': Document(page_content='회사이름: ㈜스마일게이트홀딩스, 공고이름: [스마일게이트 홀딩스] [재무] 데이터 분석 담당 (인턴), url: https://www.jobkorea.co.kr/Recruit/GI_Read/46016179?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D&listno=12, 경력: 신입, 지역: 경기, 직무: 데이터 분석'),
#  'ae586635-8aa0-4da5-91c3-b7d78bbd2aee': Document(page_content='회사이름: ㈜와이비에스, 공고이름: 도시/교통분야 빅데이터 분석 및 ai 알고리즘/모델 구현 경력직 모집, url: https://www.jobkorea.co.kr/Recruit/GI_Read/46048705?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D&listno=13, 경력: 경력, 지역: 서울, 직무: 데이터 분석'),
#  '43a2774e-bdce-4fe7-bf47-facc782a22e7': Document(page_content='회사이름: ㈜썸에이지, 공고이름: [썸에이지] 데이터 분석 담당자 모집, url: https://www.jobkorea.co.kr/Recruit/GI_Read/46036642?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D&listno=14, 경력: 경력1년↑, 지역: 경기, 직무: 데이터 분석'),
#  '4a9e0010-4f86-41f6-b0d1-fa285357391a': Document(page_content='회사이름: 씨앤토트㈜, 공고이름: 데이터 분석 및 시각화 (경력), url: https://www.jobkorea.co.kr/Recruit/GI_Read/46025939?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D&listno=15, 경력: 경력3년↑, 지역: 서울, 직무: 데이터 분석'),
#  'f9d55cb3-452a-4e7a-a1f6-aacd4c831144': Document(page_content='회사이름: 주식회사 빗썸, 공고이름: [빗썸] 데이터 분석 (인턴), url: https://www.jobkorea.co.kr/Recruit/GI_Read/45974468?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D&listno=16, 경력: 경력무관, 지역: 서울, 직무: 데이터 분석'),
#  '92fcb42c-62a0-49f9-9bd4-13dc8964fc10': Document(page_content='회사이름: ㈜아티언스, 공고이름: [글로벌 대기업 마케팅] 데이터 분석 담당 (경력), url: https://www.jobkorea.co.kr/Recruit/GI_Read/46044239?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D&listno=17, 경력: 경력5년↑, 지역: 서울, 직무: 데이터 분석'),
#  '433fb633-9594-4433-85eb-7ff5cda59caf': Document(page_content='회사이름: 인튜브, 공고이름: 빅데이터 분석 및 알고리즘 모델링 리더 모집, url: https://www.jobkorea.co.kr/Recruit/GI_Read/45686897?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D&listno=18, 경력: 경력5년↑, 지역: 서울, 직무: 데이터 분석'),
#  '20567024-87c7-44fb-88ea-022ad64a9e49': Document(page_content='회사이름: ㈜토마토시스템, 공고이름: [(주)토마토시스템] ai데이터 분석 부문 채용(신입/경력), url: https://www.jobkorea.co.kr/Recruit/GI_Read/45999830?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D&listno=19, 경력: 신입·경력3년↑, 지역: 서울, 직무: 데이터 분석'),
#  'ccb262ce-3e43-48fd-b323-5487b3a6d651': Document(page_content='회사이름: 이노뎁㈜, 공고이름: si 프로젝트 데이터 분석,설계 경력 채용 (계약직), url: https://www.jobkorea.co.kr/Recruit/GI_Read/46015025?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D&listno=20, 경력: 경력5년↑, 지역: 서울, 직무: 데이터 분석'),
#  '8b68000f-9bed-4d54-849f-b473c9e2da96': Document(page_content='회사이름: ㈜뉴엔에이아이, 공고이름: [신입 / 경력] 소셜 빅데이터 분석 컨설턴트(데이터 사이언티스트) 채용, url: https://www.jobkorea.co.kr/Recruit/GI_Read/46001387?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D&listno=21, 경력: 신입·경력3년↑, 지역: 경기, 직무: 데이터 분석'),
#  '6feb6d8a-9645-4732-8bd5-bf92d4f353be': Document(page_content='회사이름: ㈜포이시스, 공고이름: [본사] dashboard 구현을 위한 tableau 시각화 & 데이터 분석 경력직 채용, url: https://www.jobkorea.co.kr/Recruit/GI_Read/46021881?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D&listno=23, 경력: 경력무관, 지역: 서울, 직무: 데이터 분석'),
#  '3f7219fc-99c8-4694-8a6e-94d18f21b00b': Document(page_content='회사이름: 메디치이앤에스㈜, 공고이름: [빅데이터] 파이썬 데이터 분석 강사 채용, url: https://www.jobkorea.co.kr/Recruit/GI_Read/45872408?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D&listno=28, 경력: 경력, 지역: 서울, 직무: 데이터 분석'),
#  '5e43269d-0f9b-424e-80f6-6c82bc86c10f': Document(page_content='회사이름: 빔모빌리티코리아㈜, 공고이름: [빔모빌리티코리아] 전략/데이터 분석 운영담당, url: https://www.jobkorea.co.kr/Recruit/GI_Read/45976524?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D&listno=29, 경력: 경력2년↑, 지역: 서울, 직무: 데이터 분석'),
#  '37e708b3-608f-4120-b9dc-ab1e90c3aae9': Document(page_content='회사이름: ㈜테크랩스, 공고이름: [테크랩스]마케팅 데이터 분석 (브랜드엑셀러레이팅사업부), url: https://www.jobkorea.co.kr/Recruit/GI_Read/45937046?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D&listno=30, 경력: 경력2년↑, 지역: 서울, 직무: 데이터 분석'),
#  '39de6869-3045-4106-a920-8a57cca0c5d4': Document(page_content='회사이름: ㈜모비릭스, 공고이름: [모비릭스] 게임data팀 데이터 분석 경력직 모집, url: https://www.jobkorea.co.kr/Recruit/GI_Read/46005707?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D&listno=31, 경력: 경력1년↑, 지역: 서울, 직무: 데이터 분석'),
#  '62062c12-3e7b-4110-9a5f-75c1be864b54': Document(page_content='회사이름: 메디에이지, 공고이름: [헬스케어] 보건의료통계 및 데이터 분석 전문가 모집, url: https://www.jobkorea.co.kr/Recruit/GI_Read/45921749?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D&listno=32, 경력: 경력3년↑, 지역: 경기, 직무: 데이터 분석'),
#  'd49daa87-d200-4488-b3ba-81600365b477': Document(page_content='회사이름: 인튜브, 공고이름: 빅데이터 분석 및 알고리즘 모델링 사원(신입/경력) 모집, url: https://www.jobkorea.co.kr/Recruit/GI_Read/45687100?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D&listno=33, 경력: 신입·경력, 지역: 서울, 직무: 데이터 분석'),
#  'fbca8637-ba24-4d06-9333-522bb269a92a': Document(page_content='회사이름: ㈜네피리티, 공고이름: [서울] 데이터 분석 및 ai모델 개발 정규직/계약직 모집, url: https://www.jobkorea.co.kr/Recruit/GI_Read/45911857?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D&listno=34, 경력: 신입·경력3년↑, 지역: 서울, 직무: 데이터 분석'),
#  'afb6ac78-1df9-43a1-a975-ecc5452cbefe': Document(page_content='회사이름: 안진회계법인, 공고이름: [딜로이트 안진회계법인] 경영자문부문 금융기관 데이터 분석 전문가, url: https://www.jobkorea.co.kr/Recruit/GI_Read/45922645?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D&listno=35, 경력: 경력5년↑, 지역: 서울, 직무: 데이터 분석'),
#  'bf3bed35-a909-4b0e-a7d0-38a6292f1b61': Document(page_content='회사이름: ㈜일루넥스, 공고이름: 2024년 경력 인공지능, 빅데이터 분석 채용, url: https://www.jobkorea.co.kr/Recruit/GI_Read/45894712?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D&listno=36, 경력: 경력무관, 지역: 경기, 직무: 데이터 분석'),
#  'b550ad65-dfbc-4e78-858d-eebf1412baaf': Document(page_content='회사이름: 메디치이앤에스㈜, 공고이름: [빅데이터] 파이썬 데이터 분석 , 컴퓨터 비전 , ai 강사님 채용합니다, url: https://www.jobkorea.co.kr/Recruit/GI_Read/45824382?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D&listno=37, 경력: 경력, 지역: 서울, 직무: 데이터 분석'),
#  '65ef989e-ea07-4700-83a3-02372140a35e': Document(page_content='회사이름: 주식회사 맨파워코리아, 공고이름: [광화문역] 글로벌 it기업 map 데이터 분석 및 업데이트 채용 (재택 병행), url: https://www.jobkorea.co.kr/Recruit/GI_Read/46009580?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D&listno=38, 경력: 경력무관, 지역: 서울, 직무: 데이터 분석'),
#  '91172876-ca47-42e0-aedd-e91c51d1050d': Document(page_content='회사이름: 마크클라우드, 공고이름: ai 개발(python), 데이터 분석 및 사업 기획 신규/경력 모집 - 정규직, url: https://www.jobkorea.co.kr/Recruit/GI_Read/45968108?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D&listno=39, 경력: 신입·경력, 지역: 서울, 직무: 데이터 분석'),
#  '1c02a31f-2e1e-4449-a45a-f1e40626946b': Document(page_content='회사이름: 한국타이어앤테크놀로지, 공고이름: [상시채용] r&d - 데이터 수집 및 분석, url: https://www.jobkorea.co.kr/Recruit/GI_Read/45919412?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D&listno=40, 경력: 신입·경력, 지역: 대전, 직무: 데이터 분석'),
#  '60f8f26f-3a85-441a-9cd3-e110eab94635': Document(page_content='회사이름: ㈜에이브랩스, 공고이름: 데이터 분석 (data scientist) 채용, url: https://www.jobkorea.co.kr/Recruit/GI_Read/46057474?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D&listno=41, 경력: 신입·경력, 지역: 서울, 직무: 데이터 분석'),
#  'acca4551-d0cb-460d-8643-274111a6a887': Document(page_content='회사이름: ㈜파오스파트너스, 공고이름: (주)파오스파트너스 공채 채용-btl마케팅 운영 및 실행 업무, db 분석, db마케팅, url: https://www.jobkorea.co.kr/Recruit/GI_Read/45887961?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D&listno=44, 경력: 신입·경력, 지역: 서울, 직무: 데이터 분석'),
#  '77f7d802-1ccd-43e8-ae3a-154ed1d197c4': Document(page_content='회사이름: CJ 4DPLEX, 공고이름: [cj그룹 계열사] cj 4dplex 콘텐츠사업팀 데이터 분석 및 콘텐츠 실적 관리 경력직 채용, url: https://www.jobkorea.co.kr/Recruit/GI_Read/45974220?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D&listno=45, 경력: 경력3년↑, 지역: 서울, 직무: 데이터 분석'),
#  'eaaf819d-46c5-4732-a4ed-7450298226fb': Document(page_content='회사이름: ㈜에스티유니타스, 공고이름: [st unitas] 공무원 상품기획 & 데이터 분석 포지션 팀원급 인재채용, url: https://www.jobkorea.co.kr/Recruit/GI_Read/45713996?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D&listno=46, 경력: 신입, 지역: 서울, 직무: 데이터 분석'),
#  '6ff3b605-e264-429f-ae30-f301f9849800': Document(page_content='회사이름: ㈜해양정보기술, 공고이름: 해양빅데이터 분석 및 해양수치모델링 부문 정규직 채용, url: https://www.jobkorea.co.kr/Recruit/GI_Read/45913695?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D&listno=47, 경력: 경력무관, 지역: 서울, 직무: 데이터 분석'),
#  '918f0768-86fd-4345-a3b7-db223a5875ca': Document(page_content='회사이름: ㈜파오스파트너스, 공고이름: 시장 분석(리서치) 전문가 - 시장 분석, 기업 분석, 데이터 시각화, 보고서 작성, url: https://www.jobkorea.co.kr/Recruit/GI_Read/45988390?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D&listno=48, 경력: 경력, 지역: 서울, 직무: 데이터 분석'),
#  'd6d1e53b-789f-4d43-9086-13b06c3bb858': Document(page_content='회사이름: 씽킹데이터코리아㈜(THINK, 공고이름: thinkingdata 글로벌 게임 데이터 분석 솔루션 - 애널리스트 채용, url: https://www.jobkorea.co.kr/Recruit/GI_Read/46006047?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D&listno=49, 경력: 경력3년↑, 지역: 서울, 직무: 데이터 분석'),
#  '425944c6-d356-4470-ac05-e20f1b89b82a': Document(page_content='회사이름: 씨앤토트㈜, 공고이름: 빅데이터 분석 시스템 모델러, 데이터 아키텍트 (da) 모집 (경력), url: https://www.jobkorea.co.kr/Recruit/GI_Read/46003102?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D&listno=56, 경력: 경력5년↑, 지역: 서울, 직무: 데이터 분석'),
#  'eb85e0dd-29c3-44fd-bc87-f8896ca8857a': Document(page_content='회사이름: 현대엘리베이터, 공고이름: 데이터 엔지니어 경력 채용, url: https://www.jobkorea.co.kr/Recruit/GI_Read/46043051?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EC%97%94%EC%A7%80%EB%8B%88%EC%96%B4&listno=2, 경력: 경력, 지역: 서울, 직무: 데이터 엔지니어'),
#  'b81e31ca-e096-4e87-823e-b70829820999': Document(page_content='회사이름: ㈜이노케어플러스, 공고이름: 데이터 엔지니어, url: https://www.jobkorea.co.kr/Recruit/GI_Read/46046957?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EC%97%94%EC%A7%80%EB%8B%88%EC%96%B4&listno=3, 경력: 경력3년↑, 지역: 서울, 직무: 데이터 엔지니어'),
#  '799e6ef6-e0b8-4843-8fca-234afac38154': Document(page_content='회사이름: ㈜이스트에이드, 공고이름: 데이터 엔지니어 시니어, url: https://www.jobkorea.co.kr/Recruit/GI_Read/45887357?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EC%97%94%EC%A7%80%EB%8B%88%EC%96%B4&listno=4, 경력: 경력4년↑, 지역: 서울, 직무: 데이터 엔지니어'),
#  '6507ec09-88b9-4298-9b38-9758ea12a2a4': Document(page_content='회사이름: ㈜넥슨, 공고이름: [기술본부] 데이터최적화팀 데이터 엔지니어, url: https://www.jobkorea.co.kr/Recruit/GI_Read/45689858?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EC%97%94%EC%A7%80%EB%8B%88%EC%96%B4&listno=5, 경력: 경력3년↑, 지역: 경기, 직무: 데이터 엔지니어'),
#  '4a53a79a-e571-42d0-820e-f6e2362eba5f': Document(page_content='회사이름: ㈜미리디, 공고이름: [미리디] 데이터 엔지니어, url: https://www.jobkorea.co.kr/Recruit/GI_Read/45849657?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EC%97%94%EC%A7%80%EB%8B%88%EC%96%B4&listno=6, 경력: 경력5년↑, 지역: 서울, 직무: 데이터 엔지니어'),
#  'db6c8d17-229f-45de-b087-2d594e20dc83': Document(page_content='회사이름: Upstage, 공고이름: llm 시니어 데이터 엔지니어, url: https://www.jobkorea.co.kr/Recruit/GI_Read/45901824?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EC%97%94%EC%A7%80%EB%8B%88%EC%96%B4&listno=7, 경력: 경력무관, 지역: 경기, 직무: 데이터 엔지니어'),
#  'a16e470a-69e9-4a87-8b29-44adc2c05c1a': Document(page_content='회사이름: 메디웨일, 공고이름: 데이터 엔지니어, url: https://www.jobkorea.co.kr/Recruit/GI_Read/45991050?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EC%97%94%EC%A7%80%EB%8B%88%EC%96%B4&listno=8, 경력: 경력5년↑, 지역: 서울, 직무: 데이터 엔지니어'),
#  'b6c58304-aa28-415f-b423-a8879c918070': Document(page_content='회사이름: ㈜기어세컨드, 공고이름: 데이터 엔지니어(de) 채용, url: https://www.jobkorea.co.kr/Recruit/GI_Read/46009474?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EC%97%94%EC%A7%80%EB%8B%88%EC%96%B4&listno=9, 경력: 경력3년↑, 지역: 서울, 직무: 데이터 엔지니어'),
#  '78231a12-39d6-44f9-a798-403fed95a857': Document(page_content='회사이름: ㈜코세틱, 공고이름: [cosetic] 데이터 엔지니어 채용, url: https://www.jobkorea.co.kr/Recruit/GI_Read/45790860?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EC%97%94%EC%A7%80%EB%8B%88%EC%96%B4&listno=10, 경력: 경력무관, 지역: 서울, 직무: 데이터 엔지니어'),
#  'ba702817-cb18-4ab2-ac86-4a8b6e036500': Document(page_content='회사이름: ㈜카카오페이, 공고이름: 데이터 엔지니어 - 데이터플랫폼팀, url: https://www.jobkorea.co.kr/Recruit/GI_Read/46016288?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EC%97%94%EC%A7%80%EB%8B%88%EC%96%B4&listno=11, 경력: 경력5년↑, 지역: 경기, 직무: 데이터 엔지니어'),
#  'cb1b7148-f589-496f-a936-4b8ef08b287b': Document(page_content='회사이름: 로이드케이, 공고이름: 빅데이터 솔루션 데이터 엔지니어(경력) 채용, url: https://www.jobkorea.co.kr/Recruit/GI_Read/45944194?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EC%97%94%EC%A7%80%EB%8B%88%EC%96%B4&listno=13, 경력: 경력5년↑, 지역: 경기, 직무: 데이터 엔지니어'),
#  'e503ef48-345c-4540-bac9-beb17895b93d': Document(page_content='회사이름: ㈜카카오페이, 공고이름: [계약직] 데이터 엔지니어 - 분석 mart / bi 담당자, url: https://www.jobkorea.co.kr/Recruit/GI_Read/46016291?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EC%97%94%EC%A7%80%EB%8B%88%EC%96%B4&listno=14, 경력: 경력4년↑, 지역: 경기, 직무: 데이터 엔지니어'),
#  '6aa9c187-90ff-41de-830d-82dd1096b89b': Document(page_content='회사이름: ㈜커넥트웨이브, 공고이름: [커넥트웨이브] 메이크샵 데이터 엔지니어 채용(경력), url: https://www.jobkorea.co.kr/Recruit/GI_Read/45844834?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EC%97%94%EC%A7%80%EB%8B%88%EC%96%B4&listno=15, 경력: 경력3년↑, 지역: 서울, 직무: 데이터 엔지니어'),
#  'ed711423-1cba-4644-9f2b-4be2f722cfb9': Document(page_content='회사이름: ㈜카카오페이, 공고이름: 데이터 엔지니어 - dw / bi 시스템 개발 시스템 개발, url: https://www.jobkorea.co.kr/Recruit/GI_Read/46016284?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EC%97%94%EC%A7%80%EB%8B%88%EC%96%B4&listno=16, 경력: 경력5년↑, 지역: 경기, 직무: 데이터 엔지니어'),
#  '9b0162bc-fab0-4911-8be6-f8809ac505e6': Document(page_content='회사이름: 콘센트릭스서비스코리아(유), 공고이름: 데이터플랫폼엔지니어, url: https://www.jobkorea.co.kr/Recruit/GI_Read/46028427?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EC%97%94%EC%A7%80%EB%8B%88%EC%96%B4&listno=17, 경력: 경력1년↑, 지역: 서울, 직무: 데이터 엔지니어'),
#  '13681d17-1708-4051-a0b5-2d30780ee62f': Document(page_content='회사이름: ㈜와탭랩스, 공고이름: db 엔지니어, url: https://www.jobkorea.co.kr/Recruit/GI_Read/45949176?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EC%97%94%EC%A7%80%EB%8B%88%EC%96%B4&listno=18, 경력: 경력5년↑, 지역: 서울, 직무: 데이터 엔지니어'),
#  'e61a2a3c-0d3d-4f68-afe7-75ed64b54457': Document(page_content='회사이름: ㈜데이타뱅크, 공고이름: (대구)db 엔지니어 모집, url: https://www.jobkorea.co.kr/Recruit/GI_Read/46042778?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EC%97%94%EC%A7%80%EB%8B%88%EC%96%B4&listno=21, 경력: 경력무관, 지역: 대구, 직무: 데이터 엔지니어'),
#  '28a37c51-72d8-4388-a135-dedbd3425f0b': Document(page_content='회사이름: ㈜위즈베이스, 공고이름: oracle db 엔지니어, url: https://www.jobkorea.co.kr/Recruit/GI_Read/45745188?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EC%97%94%EC%A7%80%EB%8B%88%EC%96%B4&listno=22, 경력: 경력6년↑, 지역: 서울, 직무: 데이터 엔지니어'),
#  '16e00391-b55b-44b9-9fbd-04ebebcce3ab': Document(page_content='회사이름: 에이플랫폼, 공고이름: [신입/경력] database engineer - r&d center, url: https://www.jobkorea.co.kr/Recruit/GI_Read/46030703?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EC%97%94%EC%A7%80%EB%8B%88%EC%96%B4&listno=23, 경력: 신입·경력3년↑, 지역: 서울, 직무: 데이터 엔지니어'),
#  'f9ecb113-dd4e-4324-8688-88b86c22911c': Document(page_content='회사이름: ㈜에즈웰플러스, 공고이름: [경력] dba / oracle db 엔지니어 채용, url: https://www.jobkorea.co.kr/Recruit/GI_Read/45916157?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EC%97%94%EC%A7%80%EB%8B%88%EC%96%B4&listno=24, 경력: 경력3년↑, 지역: 서울, 직무: 데이터 엔지니어'),
#  'dcd141bf-12bd-4363-a45a-0965bcab07eb': Document(page_content='회사이름: 에이플랫폼, 공고이름: [신입/경력] database engineer - customer support service, url: https://www.jobkorea.co.kr/Recruit/GI_Read/46030714?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EC%97%94%EC%A7%80%EB%8B%88%EC%96%B4&listno=25, 경력: 신입·경력3년↑, 지역: 서울, 직무: 데이터 엔지니어'),
#  '64718adb-6fc8-4c68-9e69-a46404a1b19f': Document(page_content='회사이름: 에이플랫폼, 공고이름: [신입/경력] database engineer - technical solution center, url: https://www.jobkorea.co.kr/Recruit/GI_Read/46030694?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EC%97%94%EC%A7%80%EB%8B%88%EC%96%B4&listno=26, 경력: 신입·경력3년↑, 지역: 서울, 직무: 데이터 엔지니어'),
#  'a5dabee1-78b5-4205-ab46-47d422bc930d': Document(page_content='회사이름: ㈜싸이웰시스템, 공고이름: [싸이웰시스템] db 엔지니어 (신입/경력) 정규직 채용 (3200 이상), url: https://www.jobkorea.co.kr/Recruit/GI_Read/45978880?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EC%97%94%EC%A7%80%EB%8B%88%EC%96%B4&listno=28, 경력: 신입·경력, 지역: 서울, 직무: 데이터 엔지니어'),
#  '93693f6f-6460-4c59-8580-a8bfa5e89a28': Document(page_content='회사이름: 모비젠, 공고이름: (주) 모비젠 데이터 엔지니어 경력직 모집, url: https://www.jobkorea.co.kr/Recruit/GI_Read/46059155?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EC%97%94%EC%A7%80%EB%8B%88%EC%96%B4&listno=29, 경력: 경력5년↑, 지역: 경기, 직무: 데이터 엔지니어'),
#  '65cc3afc-254a-4668-9ab7-dd99d336bf2f': Document(page_content='회사이름: 라온피플㈜, 공고이름: infrastructure팀 데이터엔지니어 모집, url: https://www.jobkorea.co.kr/Recruit/GI_Read/46020510?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EC%97%94%EC%A7%80%EB%8B%88%EC%96%B4&listno=30, 경력: 경력5년↑, 지역: 경기, 직무: 데이터 엔지니어'),
#  'ddfc4f72-754b-4b80-a831-95cb75dcf78b': Document(page_content='회사이름: 마이데이터, 공고이름: airflow 경험 데이터엔지니어 구인합니다., url: https://www.jobkorea.co.kr/Recruit/GI_Read/45906290?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EC%97%94%EC%A7%80%EB%8B%88%EC%96%B4&listno=31, 경력: 경력3년↑, 지역: 서울, 직무: 데이터 엔지니어'),
#  'ac3a12f0-1c4d-477a-a787-513a264565f8': Document(page_content='회사이름: 콘센트릭스서비스코리아(유), 공고이름: 데이터엔지니어, url: https://www.jobkorea.co.kr/Recruit/GI_Read/45966661?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EC%97%94%EC%A7%80%EB%8B%88%EC%96%B4&listno=32, 경력: 경력6년↑, 지역: 서울, 직무: 데이터 엔지니어'),
#  '93fbdd2c-882e-492f-9c26-a4be88b7652e': Document(page_content='회사이름: ㈜오픈메이트, 공고이름: [오픈메이트] 데이터엔지니어, 데이터모델러, dw, etl 직무 인재 모집(정규), url: https://www.jobkorea.co.kr/Recruit/GI_Read/45985674?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EC%97%94%EC%A7%80%EB%8B%88%EC%96%B4&listno=34, 경력: 경력2년↑, 지역: 서울, 직무: 데이터 엔지니어'),
#  'b9248feb-9fdb-42db-adad-01df3bdb9e66': Document(page_content='회사이름: ㈜위즈베이스, 공고이름: oracle/tibero db 엔지니어 경력사원 모십니다., url: https://www.jobkorea.co.kr/Recruit/GI_Read/45713099?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EC%97%94%EC%A7%80%EB%8B%88%EC%96%B4&listno=36, 경력: 경력6년↑, 지역: 서울, 직무: 데이터 엔지니어'),
#  '8c64b897-fe0a-40d7-8799-29e9cbfcfa7b': Document(page_content='회사이름: ㈜두들린, 공고이름: [그리팅] data engineer - 3년 이상, url: https://www.jobkorea.co.kr/Recruit/GI_Read/45861939?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EC%97%94%EC%A7%80%EB%8B%88%EC%96%B4&listno=52, 경력: 경력3년↑, 지역: 서울, 직무: 데이터 엔지니어'),
#  'fbbf27de-1c6c-4bf8-800e-e891bb015ef4': Document(page_content='회사이름: 데이터마케팅코리아, 공고이름: (주)데이터마케팅코리아 데이터 엔지니어링 직무 채용, url: https://www.jobkorea.co.kr/Recruit/GI_Read/45902675?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EC%97%94%EC%A7%80%EB%8B%88%EC%96%B4&listno=56, 경력: 경력3년↑, 지역: 서울, 직무: 데이터 엔지니어'),
#  '392fdd7a-c68e-4fc7-a125-5dd1593667ad': Document(page_content='회사이름: ㈜유클릭, 공고이름: (주)유클릭 oracle db 경력 엔지니어 모집, url: https://www.jobkorea.co.kr/Recruit/GI_Read/45752115?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EC%97%94%EC%A7%80%EB%8B%88%EC%96%B4&listno=57, 경력: 경력5년↑, 지역: 경기, 직무: 데이터 엔지니어'),
#  '84ada5ee-e0b0-482b-93a0-870676203dc7': Document(page_content='회사이름: ㈜트릿지, 공고이름: [tridge] data engineer (산업기능요원), url: https://www.jobkorea.co.kr/Recruit/GI_Read/46030500?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EC%97%94%EC%A7%80%EB%8B%88%EC%96%B4&listno=60, 경력: 경력무관, 지역: 서울, 직무: 데이터 엔지니어'),
#  '02bfa804-2812-45bb-8a6a-bd6f382ee648': Document(page_content='회사이름: ㈜옵트에이아이, 공고이름: 임베디드 ai 개발자 (c++), url: https://www.jobkorea.co.kr/Recruit/GI_Read/45966844?Oem_Code=C1&logpath=1&stext=AI%20%EA%B0%9C%EB%B0%9C%EC%9E%90&listno=2, 경력: 경력, 지역: 서울, 직무: AI 개발자\n\n회사이름: ㈜옵트에이아이, 공고이름: 비전 ai 어플리케이션 엔지니어, url: https://www.jobkorea.co.kr/Recruit/GI_Read/45966928?Oem_Code=C1&logpath=1&stext=AI%20%EA%B0%9C%EB%B0%9C%EC%9E%90&listno=3, 경력: 경력, 지역: 서울, 직무: AI 개발자'),
#  '6d5a0624-94ba-43fc-9058-7f23e377cf3f': Document(page_content='회사이름: ㈜더존비즈온, 공고이름: [ai 개발] 더존비즈온 ai 개발자 채용, url: https://www.jobkorea.co.kr/Recruit/GI_Read/45993087?Oem_Code=C1&logpath=1&stext=AI%20%EA%B0%9C%EB%B0%9C%EC%9E%90&listno=5, 경력: 경력1년↑, 지역: 강원, 직무: AI 개발자'),
#  '3b83479f-7e74-49f2-a19e-2379abf12a8c': Document(page_content='회사이름: 주식회사 솔트룩스, 공고이름: 인공지능(ai) 솔트룩스 - nlp research engineer 경력, url: https://www.jobkorea.co.kr/Recruit/GI_Read/45862140?Oem_Code=C1&logpath=1&stext=AI%20%EA%B0%9C%EB%B0%9C%EC%9E%90&listno=6, 경력: 경력2년↑, 지역: 서울, 직무: AI 개발자'),
#  '760fa96a-7d3b-4fb0-a5aa-47484c53ac66': Document(page_content='회사이름: ㈜에이아이포블록체인(AI4 Blo, 공고이름: (경력) 인공지능 개발자 채용, url: https://www.jobkorea.co.kr/Recruit/GI_Read/45994009?Oem_Code=C1&logpath=1&stext=AI%20%EA%B0%9C%EB%B0%9C%EC%9E%90&listno=7, 경력: 경력1년↑, 지역: 경기, 직무: AI 개발자'),
#  'fa39872c-d125-4f43-9930-c9086bc0a95e': Document(page_content='회사이름: ㈜아이스크림아트, 공고이름: ai연구소 ai기반 연구팀장, url: https://www.jobkorea.co.kr/Recruit/GI_Read/46036137?Oem_Code=C1&logpath=1&stext=AI%20%EA%B0%9C%EB%B0%9C%EC%9E%90&listno=8, 경력: 경력7년↑, 지역: 서울, 직무: AI 개발자'),
#  'b8faba27-a814-4c60-9e7b-b14a2ee2e7df': Document(page_content='회사이름: 주식회사 솔트룩스, 공고이름: 인공지능(ai) 솔트룩스 - nlp research engineer 신입, url: https://www.jobkorea.co.kr/Recruit/GI_Read/45846865?Oem_Code=C1&logpath=1&stext=AI%20%EA%B0%9C%EB%B0%9C%EC%9E%90&listno=9, 경력: 신입, 지역: 서울, 직무: AI 개발자\n\n회사이름: ㈜웅진, 공고이름: [경력] ai개발자, url: https://www.jobkorea.co.kr/Recruit/GI_Read/46011182?Oem_Code=C1&logpath=1&stext=AI%20%EA%B0%9C%EB%B0%9C%EC%9E%90&listno=10, 경력: 경력3년↑, 지역: 서울, 직무: AI 개발자'),
#  'e4633b59-2aa2-4517-9450-ba4ae55e23d2': Document(page_content='회사이름: ㈜웅진, 공고이름: [경력] ai개발자, url: https://www.jobkorea.co.kr/Recruit/GI_Read/46011182?Oem_Code=C1&logpath=1&stext=AI%20%EA%B0%9C%EB%B0%9C%EC%9E%90&listno=10, 경력: 경력3년↑, 지역: 서울, 직무: AI 개발자\n\n회사이름: 퀘이자㈜, 공고이름: ai기반 감정서비스 개발자 모집, url: https://www.jobkorea.co.kr/Recruit/GI_Read/45870888?Oem_Code=C1&logpath=1&stext=AI%20%EA%B0%9C%EB%B0%9C%EC%9E%90&listno=11, 경력: 경력, 지역: 인천, 직무: AI 개발자'),
#  'dc170503-1a65-4c74-a389-57692cebe713': Document(page_content='회사이름: 퀘이자㈜, 공고이름: ai기반 감정서비스 개발자 모집, url: https://www.jobkorea.co.kr/Recruit/GI_Read/45870888?Oem_Code=C1&logpath=1&stext=AI%20%EA%B0%9C%EB%B0%9C%EC%9E%90&listno=11, 경력: 경력, 지역: 인천, 직무: AI 개발자\n\n회사이름: ㈜크래프톤, 공고이름: [ai] ai engineer - nlp/chatbot (3년 이상), url: https://www.jobkorea.co.kr/Recruit/GI_Read/45826591?Oem_Code=C1&logpath=1&stext=AI%20%EA%B0%9C%EB%B0%9C%EC%9E%90&listno=12, 경력: 경력, 지역: 서울, 직무: AI 개발자'),
#  'c629dbf2-699f-4bd1-b546-2b5eba51c978': Document(page_content='회사이름: ㈜크래프톤, 공고이름: [ai] ai engineer - nlp/chatbot (3년 이상), url: https://www.jobkorea.co.kr/Recruit/GI_Read/45826591?Oem_Code=C1&logpath=1&stext=AI%20%EA%B0%9C%EB%B0%9C%EC%9E%90&listno=12, 경력: 경력, 지역: 서울, 직무: AI 개발자\n\n회사이름: ㈜미피아(Mippia Inc., 공고이름: 음원 유사도 분석 ai 엔지니어 모집, url: https://www.jobkorea.co.kr/Recruit/GI_Read/45889185?Oem_Code=C1&logpath=1&stext=AI%20%EA%B0%9C%EB%B0%9C%EC%9E%90&listno=13, 경력: 신입, 지역: 서울, 직무: AI 개발자'),
#  'e46b850d-56c3-4164-a5c6-bf77d6ddcfc2': Document(page_content='회사이름: ㈜옵트에이아이, 공고이름: [병역특례]임베디드 ai 개발자 (c++), url: https://www.jobkorea.co.kr/Recruit/GI_Read/45965544?Oem_Code=C1&logpath=1&stext=AI%20%EA%B0%9C%EB%B0%9C%EC%9E%90&listno=14, 경력: 경력1년↑, 지역: 서울, 직무: AI 개발자'),
#  '7c6d14d5-35a4-42e4-a121-6af741c53b67': Document(page_content='회사이름: ㈜옵트에이아이, 공고이름: [병역특례]비전 ai 어플리케이션 엔지니어, url: https://www.jobkorea.co.kr/Recruit/GI_Read/45965497?Oem_Code=C1&logpath=1&stext=AI%20%EA%B0%9C%EB%B0%9C%EC%9E%90&listno=17, 경력: 경력1년↑, 지역: 서울, 직무: AI 개발자'),
#  'e9d7f04a-d028-4d4b-b9a5-a7a164711ffc': Document(page_content='회사이름: ㈜포니링크, 공고이름: (주)포니링크 ai개발자 경력직 채용, url: https://www.jobkorea.co.kr/Recruit/GI_Read/45953125?Oem_Code=C1&logpath=1&stext=AI%20%EA%B0%9C%EB%B0%9C%EC%9E%90&listno=18, 경력: 경력5년↑, 지역: 서울, 직무: AI 개발자'),
#  '1b0b8099-d3b9-4b0b-ac03-28baeda887ef': Document(page_content='회사이름: ㈜이오테크닉스, 공고이름: (주)이오테크닉스 ai개발자 모집, url: https://www.jobkorea.co.kr/Recruit/GI_Read/45952853?Oem_Code=C1&logpath=1&stext=AI%20%EA%B0%9C%EB%B0%9C%EC%9E%90&listno=20, 경력: 경력, 지역: 경기, 직무: AI 개발자'),
#  'bed0b570-68e6-49a6-a25a-0e0eef3f55da': Document(page_content='회사이름: 오투오, 공고이름: (주)에이아이오투오 ai 개발자 채용, url: https://www.jobkorea.co.kr/Recruit/GI_Read/46013600?Oem_Code=C1&logpath=1&stext=AI%20%EA%B0%9C%EB%B0%9C%EC%9E%90&listno=21, 경력: 경력무관, 지역: 경기, 직무: AI 개발자\n\n회사이름: 그로들, 공고이름: ai llm 개발자, url: https://www.jobkorea.co.kr/Recruit/GI_Read/46035561?Oem_Code=C1&logpath=1&stext=AI%20%EA%B0%9C%EB%B0%9C%EC%9E%90&listno=22, 경력: 경력6년↑, 지역: 서울, 직무: AI 개발자'),
#  '473c915e-f048-4fd0-ae72-8fa44f7c8fd2': Document(page_content='회사이름: 그로들, 공고이름: ai llm 개발자, url: https://www.jobkorea.co.kr/Recruit/GI_Read/46035561?Oem_Code=C1&logpath=1&stext=AI%20%EA%B0%9C%EB%B0%9C%EC%9E%90&listno=22, 경력: 경력6년↑, 지역: 서울, 직무: AI 개발자\n\n회사이름: ㈜숲(SOOP CO., LTD.), 공고이름: [soop] ai 엔지니어 리더, url: https://www.jobkorea.co.kr/Recruit/GI_Read/45965928?Oem_Code=C1&logpath=1&stext=AI%20%EA%B0%9C%EB%B0%9C%EC%9E%90&listno=23, 경력: 경력6년↑, 지역: 경기, 직무: AI 개발자'),
#  '5771abfd-9596-4c31-b6e8-6dd48be9fbb9': Document(page_content='회사이름: ㈜숲(SOOP CO., LTD.), 공고이름: [soop] ai 엔지니어 리더, url: https://www.jobkorea.co.kr/Recruit/GI_Read/45965928?Oem_Code=C1&logpath=1&stext=AI%20%EA%B0%9C%EB%B0%9C%EC%9E%90&listno=23, 경력: 경력6년↑, 지역: 경기, 직무: AI 개발자\n\n회사이름: 한국딥러닝㈜, 공고이름: ai 엔지니어(데이터), url: https://www.jobkorea.co.kr/Recruit/GI_Read/46026864?Oem_Code=C1&logpath=1&stext=AI%20%EA%B0%9C%EB%B0%9C%EC%9E%90&listno=24, 경력: 경력3년↑, 지역: 서울, 직무: AI 개발자'),
#  'e06787e5-53b1-45e1-a7d0-1758afe28420': Document(page_content='회사이름: 한국딥러닝㈜, 공고이름: ai 엔지니어(데이터), url: https://www.jobkorea.co.kr/Recruit/GI_Read/46026864?Oem_Code=C1&logpath=1&stext=AI%20%EA%B0%9C%EB%B0%9C%EC%9E%90&listno=24, 경력: 경력3년↑, 지역: 서울, 직무: AI 개발자\n\n회사이름: ㈜헥토, 공고이름: [헥토 ai랩] ai 테크팀 (software engineer, ml), url: https://www.jobkorea.co.kr/Recruit/GI_Read/45864920?Oem_Code=C1&logpath=1&stext=AI%20%EA%B0%9C%EB%B0%9C%EC%9E%90&listno=25, 경력: 경력8년↑, 지역: 서울, 직무: AI 개발자'),
#  '10db61ac-0a44-43e0-932a-2e5e4062b170': Document(page_content='회사이름: ㈜헥토, 공고이름: [헥토 ai랩] ai 테크팀 (software engineer, ml), url: https://www.jobkorea.co.kr/Recruit/GI_Read/45864920?Oem_Code=C1&logpath=1&stext=AI%20%EA%B0%9C%EB%B0%9C%EC%9E%90&listno=25, 경력: 경력8년↑, 지역: 서울, 직무: AI 개발자\n\n회사이름: ㈜네비웍스, 공고이름: ai 개발자(경력), url: https://www.jobkorea.co.kr/Recruit/GI_Read/45997908?Oem_Code=C1&logpath=1&stext=AI%20%EA%B0%9C%EB%B0%9C%EC%9E%90&listno=26, 경력: 경력1년↑, 지역: 경기, 직무: AI 개발자'),
#  'cfcfad8a-ed12-41e3-a6c6-96a9282c25f8': Document(page_content='회사이름: ㈜네비웍스, 공고이름: ai 개발자(경력), url: https://www.jobkorea.co.kr/Recruit/GI_Read/45997908?Oem_Code=C1&logpath=1&stext=AI%20%EA%B0%9C%EB%B0%9C%EC%9E%90&listno=26, 경력: 경력1년↑, 지역: 경기, 직무: AI 개발자\n\n회사이름: ㈜휴라이트, 공고이름: ai/ml 인공지능 엔지니어, url: https://www.jobkorea.co.kr/Recruit/GI_Read/45941699?Oem_Code=C1&logpath=1&stext=AI%20%EA%B0%9C%EB%B0%9C%EC%9E%90&listno=27, 경력: 경력3년↑, 지역: 경기, 직무: AI 개발자'),
#  'c13455b7-e945-4606-bf9d-cfb62ba90d97': Document(page_content='회사이름: ㈜아이스크림아트, 공고이름: ai연구소 ai기반 연구팀원 (경력), url: https://www.jobkorea.co.kr/Recruit/GI_Read/46036173?Oem_Code=C1&logpath=1&stext=AI%20%EA%B0%9C%EB%B0%9C%EC%9E%90&listno=29, 경력: 경력5년↑, 지역: 서울, 직무: AI 개발자'),
#  '04ba9069-2ebc-46c4-8f84-e58d934613b1': Document(page_content='회사이름: 코아텍㈜, 공고이름: 인공지능 실무업무 경력자(it개발, ai, 전기전자), url: https://www.jobkorea.co.kr/Recruit/GI_Read/46032532?Oem_Code=C1&logpath=1&stext=AI%20%EA%B0%9C%EB%B0%9C%EC%9E%90&listno=30, 경력: 경력5년↑, 지역: 경기, 직무: AI 개발자'),
#  'bfa9dca5-d120-4c87-a00a-18d6e93373d0': Document(page_content='회사이름: ㈜펨트론, 공고이름: [펨트론] 3d&ai팀 ct알고리즘 개발자, url: https://www.jobkorea.co.kr/Recruit/GI_Read/45998579?Oem_Code=C1&logpath=1&stext=AI%20%EA%B0%9C%EB%B0%9C%EC%9E%90&listno=31, 경력: 신입·경력, 지역: 서울, 직무: AI 개발자'),
#  '535feaca-92a1-4b24-8483-cec43ae60036': Document(page_content='회사이름: ㈜CJ올리브네트웍스, 공고이름: [경력] llm 분야 생성형 ai 엔지니어, url: https://www.jobkorea.co.kr/Recruit/GI_Read/45973594?Oem_Code=C1&logpath=1&stext=AI%20%EA%B0%9C%EB%B0%9C%EC%9E%90&listno=34, 경력: 경력, 지역: 서울, 직무: AI 개발자'),
#  '8bb692de-e2c2-4302-9f76-52c8c0be27ce': Document(page_content='회사이름: ㈜미니게이트, 공고이름: [경력 3년 이상] ml(ai) engineer 모집합니다., url: https://www.jobkorea.co.kr/Recruit/GI_Read/45994118?Oem_Code=C1&logpath=1&stext=AI%20%EA%B0%9C%EB%B0%9C%EC%9E%90&listno=36, 경력: 경력3년↑, 지역: 서울, 직무: AI 개발자'),
#  'e39b919a-bde6-417f-8add-ba6b059575fa': Document(page_content='회사이름: ㈜아이스크림아트, 공고이름: (주)아이스크림아트 ai연구소 ai기반연구팀장/팀원(경력) 채용, url: https://www.jobkorea.co.kr/Recruit/GI_Read/45993989?Oem_Code=C1&logpath=1&stext=AI%20%EA%B0%9C%EB%B0%9C%EC%9E%90&listno=37, 경력: 경력5년↑, 지역: 서울, 직무: AI 개발자'),
#  '923c0e56-b4c6-4966-8e69-0f007f39969a': Document(page_content='회사이름: 티엔에스에이아이㈜, 공고이름: ai(인공지능) 딥러닝 개발자 모집 인재채용, url: https://www.jobkorea.co.kr/Recruit/GI_Read/45867335?Oem_Code=C1&logpath=1&stext=AI%20%EA%B0%9C%EB%B0%9C%EC%9E%90&listno=38, 경력: 신입·경력3년↑, 지역: 인천, 직무: AI 개발자'),
#  'b88e2b42-31c9-4278-a6a1-20fcfc163d79': Document(page_content='회사이름: ㈜엑스큐어넷, 공고이름: 생성형 ai 모델 연구 및 응용 개발(ai/ml), url: https://www.jobkorea.co.kr/Recruit/GI_Read/45895377?Oem_Code=C1&logpath=1&stext=AI%20%EA%B0%9C%EB%B0%9C%EC%9E%90&listno=39, 경력: 경력3년↑, 지역: 서울, 직무: AI 개발자'),
#  '7021aec7-ec39-40d0-929c-a0906658845b': Document(page_content='회사이름: ㈜인피닉, 공고이름: [인공지능 연구소] ai 알고리즘 개발자 채용 (신입, 경력, 병역특례), url: https://www.jobkorea.co.kr/Recruit/GI_Read/45703288?Oem_Code=C1&logpath=1&stext=AI%20%EA%B0%9C%EB%B0%9C%EC%9E%90&listno=40, 경력: 신입·경력, 지역: 서울, 직무: AI 개발자'),
#  '0c3ba09d-002e-4ccc-9a64-03b2e3f21163': Document(page_content='회사이름: ㈜미니레코드, 공고이름: ai 개발자, url: https://www.jobkorea.co.kr/Recruit/GI_Read/45901759?Oem_Code=C1&logpath=1&stext=AI%20%EA%B0%9C%EB%B0%9C%EC%9E%90&listno=41, 경력: 경력2년↑, 지역: 서울, 직무: AI 개발자\n\n회사이름: 섬재㈜, 공고이름: ai researcher, url: https://www.jobkorea.co.kr/Recruit/GI_Read/45927329?Oem_Code=C1&logpath=1&stext=AI%20%EA%B0%9C%EB%B0%9C%EC%9E%90&listno=42, 경력: 경력3년↑, 지역: 서울, 직무: AI 개발자'),
#  '57d88ba8-d3cd-4ccc-841b-777da88af6f5': Document(page_content='회사이름: 슈프리마, 공고이름: [슈프리마 ai] 얼굴인식/비디오 분석 인공지능 알고리즘 개발자 모집, url: https://www.jobkorea.co.kr/Recruit/GI_Read/45888195?Oem_Code=C1&logpath=1&stext=AI%20%EA%B0%9C%EB%B0%9C%EC%9E%90&listno=43, 경력: 신입·경력2년↑, 지역: 경기, 직무: AI 개발자'),
#  '57e6b72d-6525-4792-aae1-f41630a2ac53': Document(page_content='회사이름: ㈜트루엔, 공고이름: on-device ai 개발자 적극채용 (truen), url: https://www.jobkorea.co.kr/Recruit/GI_Read/45933525?Oem_Code=C1&logpath=1&stext=AI%20%EA%B0%9C%EB%B0%9C%EC%9E%90&listno=44, 경력: 경력7년↑, 지역: 서울, 직무: AI 개발자\n\n회사이름: 빅웨이브로보틱스㈜, 공고이름: ai researcher, url: https://www.jobkorea.co.kr/Recruit/GI_Read/46057863?Oem_Code=C1&logpath=1&stext=AI%20%EA%B0%9C%EB%B0%9C%EC%9E%90&listno=46, 경력: 경력, 지역: 서울, 직무: AI 개발자'),
#  'd52e0fc6-e502-428f-aa38-cde25f8547fe': Document(page_content='회사이름: 빅웨이브로보틱스㈜, 공고이름: ai researcher, url: https://www.jobkorea.co.kr/Recruit/GI_Read/46057863?Oem_Code=C1&logpath=1&stext=AI%20%EA%B0%9C%EB%B0%9C%EC%9E%90&listno=46, 경력: 경력, 지역: 서울, 직무: AI 개발자\n\n회사이름: ㈜펄어비스, 공고이름: [펄어비스] [신입/경력] ai 엔지니어 모집, url: https://www.jobkorea.co.kr/Recruit/GI_Read/46012629?Oem_Code=C1&logpath=1&stext=AI%20%EA%B0%9C%EB%B0%9C%EC%9E%90&listno=47, 경력: 경력무관, 지역: 경기, 직무: AI 개발자'),
#  'e5c07dea-b614-41dd-bb2b-4101db9308c3': Document(page_content='회사이름: ㈜미니게이트, 공고이름: [경력 3년 이상] ml(ai) engineer 모집, url: https://www.jobkorea.co.kr/Recruit/GI_Read/45950375?Oem_Code=C1&logpath=1&stext=AI%20%EA%B0%9C%EB%B0%9C%EC%9E%90&listno=48, 경력: 경력3년↑, 지역: 서울, 직무: AI 개발자\n\n회사이름: 다큐브㈜, 공고이름: ai 엔지니어 (llm, nlp), url: https://www.jobkorea.co.kr/Recruit/GI_Read/45996079?Oem_Code=C1&logpath=1&stext=AI%20%EA%B0%9C%EB%B0%9C%EC%9E%90&listno=50, 경력: 경력5년↑, 지역: 서울, 직무: AI 개발자'),
#  '9324cbe2-51e0-4dc6-b74a-dbeaafc1fd33': Document(page_content='회사이름: 다큐브㈜, 공고이름: ai 엔지니어 (llm, nlp), url: https://www.jobkorea.co.kr/Recruit/GI_Read/45996079?Oem_Code=C1&logpath=1&stext=AI%20%EA%B0%9C%EB%B0%9C%EC%9E%90&listno=50, 경력: 경력5년↑, 지역: 서울, 직무: AI 개발자\n\n회사이름: 엔에이치엔㈜, 공고이름: [nhn] 음성 ai 연구/개발, url: https://www.jobkorea.co.kr/Recruit/GI_Read/45799959?Oem_Code=C1&logpath=1&stext=AI%20%EA%B0%9C%EB%B0%9C%EC%9E%90&listno=51, 경력: 경력무관, 지역: 경기, 직무: AI 개발자'),
#  'c0b2c10f-0cae-43a6-8a48-2c3c171a672a': Document(page_content='회사이름: 가온그룹㈜, 공고이름: [가온그룹] ai 백엔드 개발 담당 채용, url: https://www.jobkorea.co.kr/Recruit/GI_Read/45966069?Oem_Code=C1&logpath=1&stext=AI%20%EA%B0%9C%EB%B0%9C%EC%9E%90&listno=53, 경력: 경력무관, 지역: 경기, 직무: AI 개발자'),
#  '3e181609-e5c9-4fe7-ad64-0a36d036b05e': Document(page_content='회사이름: ㈜뉴엔에이아이, 공고이름: [신입/경력] 인공지능 딥러닝 개발자 모집, url: https://www.jobkorea.co.kr/Recruit/GI_Read/45976037?Oem_Code=C1&logpath=1&stext=AI%20%EA%B0%9C%EB%B0%9C%EC%9E%90&listno=54, 경력: 신입·경력1년↑, 지역: 경기, 직무: AI 개발자'),
#  '980f43c6-8105-4285-8e33-1472a419dafc': Document(page_content='회사이름: ㈜알라딘커뮤니케이션, 공고이름: ai 엔지니어 개발자, url: https://www.jobkorea.co.kr/Recruit/GI_Read/45962660?Oem_Code=C1&logpath=1&stext=AI%20%EA%B0%9C%EB%B0%9C%EC%9E%90&listno=55, 경력: 경력5년↑, 지역: 서울, 직무: AI 개발자'),
#  'b85d48df-035c-4e19-8605-ef1aaf2be124': Document(page_content='회사이름: ㈜비아이매트릭스, 공고이름: [코스닥기업] 생성형 ai 엔지니어 채용, url: https://www.jobkorea.co.kr/Recruit/GI_Read/46029095?Oem_Code=C1&logpath=1&stext=AI%20%EA%B0%9C%EB%B0%9C%EC%9E%90&listno=56, 경력: 경력5년↑, 지역: 서울, 직무: AI 개발자'),
#  '73554c7d-ce94-4ae6-acb0-b7c95bc29927': Document(page_content='회사이름: 알서포트㈜, 공고이름: [코스닥상장사] ai 기반 제품/서비스 개발자 채용, url: https://www.jobkorea.co.kr/Recruit/GI_Read/45991651?Oem_Code=C1&logpath=1&stext=AI%20%EA%B0%9C%EB%B0%9C%EC%9E%90&listno=57, 경력: 경력3년↑, 지역: 서울, 직무: AI 개발자'),
#  'f66d4e37-7ff3-4cf7-a16c-ef1d560a5984': Document(page_content='회사이름: 에스이에스에이아이코리아 유한회사, 공고이름: senior ai/ml engineer, url: https://www.jobkorea.co.kr/Recruit/GI_Read/45875000?Oem_Code=C1&logpath=1&stext=AI%20%EA%B0%9C%EB%B0%9C%EC%9E%90&listno=58, 경력: 경력5년↑, 지역: 경기, 직무: AI 개발자\n\n회사이름: 프보이㈜, 공고이름: vision 분야 ai 경력 개발자 채용, url: https://www.jobkorea.co.kr/Recruit/GI_Read/45954925?Oem_Code=C1&logpath=1&stext=AI%20%EA%B0%9C%EB%B0%9C%EC%9E%90&listno=59, 경력: 경력2년↑, 지역: 부산, 직무: AI 개발자'),
#  '71f038a5-70d3-4530-be40-07c9488222f0': Document(page_content='회사이름: ㈜인피닉, 공고이름: [인공지능 연구소] 인공지능 및 지식그래프 연구/개발 신입 및 경력 채용, url: https://www.jobkorea.co.kr/Recruit/GI_Read/45987107?Oem_Code=C1&logpath=1&stext=AI%20%EA%B0%9C%EB%B0%9C%EC%9E%90&listno=60, 경력: 경력무관, 지역: 서울, 직무: AI 개발자'),
#  '62724e08-1eab-4398-b412-33f16e212c66': Document(page_content='회사이름: ㈜메이크봇, 공고이름: ai챗봇 선두기업, java/php 웹개발자 채용, url: https://www.jobkorea.co.kr/Recruit/GI_Read/46033261?Oem_Code=C1&logpath=1&stext=%EC%B1%97%EB%B4%87%20%EA%B0%9C%EB%B0%9C%EC%9E%90&listno=1, 경력: 신입·경력, 지역: 서울, 직무: 챗봇 개발자'),
#  'c25e2178-610e-46db-a9da-f6ef04f5b5fa': Document(page_content='회사이름: ㈜스피링크, 공고이름: [인재풀] ai 챗봇 개발 프리랜서 상시 모집(back/front), url: https://www.jobkorea.co.kr/Recruit/GI_Read/45924777?Oem_Code=C1&logpath=1&stext=%EC%B1%97%EB%B4%87%20%EA%B0%9C%EB%B0%9C%EC%9E%90&listno=2, 경력: 경력5년↑, 지역: 서울, 직무: 챗봇 개발자'),
#  'e82b1f6f-c3fb-4097-865e-b96bcdec1a47': Document(page_content='회사이름: ㈜메이크봇, 공고이름: ai챗봇 선두기업, 전문연구요원(병역특례) 채용(ai/sw 연구개발), url: https://www.jobkorea.co.kr/Recruit/GI_Read/45868586?Oem_Code=C1&logpath=1&stext=%EC%B1%97%EB%B4%87%20%EA%B0%9C%EB%B0%9C%EC%9E%90&listno=7, 경력: 신입·경력, 지역: 서울, 직무: 챗봇 개발자'),
#  'd7a56c39-b065-4fea-8c75-567651157e5c': Document(page_content='회사이름: ㈜새롬정보시스템, 공고이름: gen ai 기반 응용솔루션 웹개발(ai사업부문) 경력사원 채용공고, url: https://www.jobkorea.co.kr/Recruit/GI_Read/46036704?Oem_Code=C1&logpath=1&stext=%EC%B1%97%EB%B4%87%20%EA%B0%9C%EB%B0%9C%EC%9E%90&listno=8, 경력: 경력3년↑, 지역: 서울, 직무: 챗봇 개발자'),
#  'b991f54c-4f74-45ea-8499-56bc0d303267': Document(page_content='회사이름: ㈜천재교육, 공고이름: [천재교육] ai센터 언어처리팀 각 부문별 개발자 모집(경력), url: https://www.jobkorea.co.kr/Recruit/GI_Read/46013479?Oem_Code=C1&logpath=1&stext=%EC%B1%97%EB%B4%87%20%EA%B0%9C%EB%B0%9C%EC%9E%90&listno=25, 경력: 경력5년↑, 지역: 서울, 직무: 챗봇 개발자'),
#  '97e9686c-e8c0-4772-93c9-5dc9b408c444': Document(page_content='회사이름: ㈜누리미디어, 공고이름: [개발운영] 시니어 ai 개발자 (경력), url: https://www.jobkorea.co.kr/Recruit/GI_Read/45820632?Oem_Code=C1&logpath=1&stext=%EC%B1%97%EB%B4%87%20%EA%B0%9C%EB%B0%9C%EC%9E%90&listno=39, 경력: 경력7년↑, 지역: 서울, 직무: 챗봇 개발자'),
#  'd613d5b3-1bd9-4f14-bd2a-98b4ec0b7916': Document(page_content='회사이름: ㈜에스지시큐리티컨설팅, 공고이름: [신입/경력]ai 개발자, url: https://www.jobkorea.co.kr/Recruit/GI_Read/45978474?Oem_Code=C1&logpath=1&stext=%EC%B1%97%EB%B4%87%20%EA%B0%9C%EB%B0%9C%EC%9E%90&listno=40, 경력: 신입·경력1년↑, 지역: 서울, 직무: 챗봇 개발자'),
#  'd6ce1dec-c019-4e70-9c72-36694af9f409': Document(page_content='회사이름: 메타빌드㈜, 공고이름: 메타빌드(주) ai 개발자 인재 채용, url: https://www.jobkorea.co.kr/Recruit/GI_Read/45906098?Oem_Code=C1&logpath=1&stext=%EC%B1%97%EB%B4%87%20%EA%B0%9C%EB%B0%9C%EC%9E%90&listno=41, 경력: 경력무관, 지역: 서울, 직무: 챗봇 개발자'),
#  'b6c4af21-0894-4a94-938f-fa6a9b01702c': Document(page_content='회사이름: ㈜페르소나에이아이, 공고이름: 인공지능(ai) 솔루션 php 개발자 채용, url: https://www.jobkorea.co.kr/Recruit/GI_Read/46048610?Oem_Code=C1&logpath=1&stext=%EC%B1%97%EB%B4%87%20%EA%B0%9C%EB%B0%9C%EC%9E%90&listno=42, 경력: 경력5년↑, 지역: 서울, 직무: 챗봇 개발자'),
#  'ee284491-1a1f-4926-8c7b-a27942cfef60': Document(page_content='회사이름: 알파브릿지㈜, 공고이름: 프론트엔드 시니어 개발자 채용, url: https://www.jobkorea.co.kr/Recruit/GI_Read/45907088?Oem_Code=C1&logpath=1&stext=%EC%B1%97%EB%B4%87%20%EA%B0%9C%EB%B0%9C%EC%9E%90&listno=43, 경력: 경력5년↑, 지역: 경기, 직무: 챗봇 개발자'),
#  '381f04b8-446d-458f-b499-1c406e81e6f1': Document(page_content='회사이름: ㈜페르소나에이아이, 공고이름: ai 음성인식 개발자 채용, url: https://www.jobkorea.co.kr/Recruit/GI_Read/45946096?Oem_Code=C1&logpath=1&stext=%EC%B1%97%EB%B4%87%20%EA%B0%9C%EB%B0%9C%EC%9E%90&listno=46, 경력: 경력5년↑, 지역: 서울, 직무: 챗봇 개발자'),
#  '52f84997-b591-4727-97fa-3ddf676c672f': Document(page_content='회사이름: ㈜페르소나에이아이, 공고이름: ai음성 솔루션 java 개발자 채용, url: https://www.jobkorea.co.kr/Recruit/GI_Read/45872361?Oem_Code=C1&logpath=1&stext=%EC%B1%97%EB%B4%87%20%EA%B0%9C%EB%B0%9C%EC%9E%90&listno=47, 경력: 경력5년↑, 지역: 서울, 직무: 챗봇 개발자'),
#  'aa7522ab-7804-4445-ad02-cf1358049fc6': Document(page_content='회사이름: ㈜미니레코드, 공고이름: react native 개발자, url: https://www.jobkorea.co.kr/Recruit/GI_Read/45901722?Oem_Code=C1&logpath=1&stext=%EC%B1%97%EB%B4%87%20%EA%B0%9C%EB%B0%9C%EC%9E%90&listno=51, 경력: 경력1년↑, 지역: 서울, 직무: 챗봇 개발자'),
#  '8d8a4311-46b7-4327-ad0c-d94f9276753f': Document(page_content='회사이름: ㈜레인보우브레인, 공고이름: [플랫폼사업본부] 금융권 ai 서비스 프론트엔드개발자, url: https://www.jobkorea.co.kr/Recruit/GI_Read/45683096?Oem_Code=C1&logpath=1&stext=%EC%B1%97%EB%B4%87%20%EA%B0%9C%EB%B0%9C%EC%9E%90&listno=54, 경력: 경력2년↑, 지역: 서울, 직무: 챗봇 개발자'),
#  '1d17f1aa-1c42-4d54-8d54-754a7f078129': Document(page_content='회사이름: ㈜인티그리트, 공고이름: [차세대 ai 로보틱스 플랫폼] 인티그리트와 함께 해주실 역량있는 개발자를 모십니다 [r&d 부분), url: https://www.jobkorea.co.kr/Recruit/GI_Read/45959822?Oem_Code=C1&logpath=1&stext=%EC%B1%97%EB%B4%87%20%EA%B0%9C%EB%B0%9C%EC%9E%90&listno=56, 경력: 경력, 지역: 서울, 직무: 챗봇 개발자'),
#  'a3f808fd-84bc-4f87-891f-18d316953494': Document(page_content='회사이름: ㈜스피링크, 공고이름: [textnet] llm 기반 풀스택 개발자 채용, url: https://www.jobkorea.co.kr/Recruit/GI_Read/45989449?Oem_Code=C1&logpath=1&stext=%EC%B1%97%EB%B4%87%20%EA%B0%9C%EB%B0%9C%EC%9E%90&listno=57, 경력: 경력3년↑, 지역: 서울, 직무: 챗봇 개발자'),
#  '89abc4bb-c220-4001-80ca-56559218ad13': Document(page_content='회사이름: ㈜한국클라우드, 공고이름: (주)한국클라우드 프론트엔드 개발자 정규직 채용, url: https://www.jobkorea.co.kr/Recruit/GI_Read/45892269?Oem_Code=C1&logpath=1&stext=%EC%B1%97%EB%B4%87%20%EA%B0%9C%EB%B0%9C%EC%9E%90&listno=58, 경력: 경력무관, 지역: 서울, 직무: 챗봇 개발자'),
#  'dcce4280-c19b-4362-9ee9-f5b816748006': Document(page_content='회사이름: 중소기업(300명이하), 공고이름: 솔루션개발 및 구축 pl(챗봇 기획 경력), url: https://www.jobkorea.co.kr/Recruit/GI_Read/46008997?PageGbn=HH&logpath=1&stext=%EC%B1%97%EB%B4%87%20%EA%B0%9C%EB%B0%9C%EC%9E%90&listno=60, 경력: 경력7년↑, 지역: 경기, 직무: 챗봇 개발자'),
#  '9319d83f-5996-4b02-b214-c88f247f28f6': Document(page_content='회사이름: 어빌리티 시스템즈, 공고이름: 클라우드 엔지니어 채용, url: https://www.jobkorea.co.kr/Recruit/GI_Read/45924314?Oem_Code=C1&logpath=1&stext=%ED%81%B4%EB%9D%BC%EC%9A%B0%EB%93%9C%20%EC%97%94%EC%A7%80%EB%8B%88%EC%96%B4&listno=1, 경력: 신입·경력2년↑, 지역: 서울, 직무: 클라우드 엔지니어'),
#  '571f5a70-f5ea-45c3-b706-1e3a709698e3': Document(page_content='회사이름: ㈜투스카이, 공고이름: cloud 엔지니어 모집, url: https://www.jobkorea.co.kr/Recruit/GI_Read/46034880?Oem_Code=C1&logpath=1&stext=%ED%81%B4%EB%9D%BC%EC%9A%B0%EB%93%9C%20%EC%97%94%EC%A7%80%EB%8B%88%EC%96%B4&listno=2, 경력: 경력5년↑, 지역: 서울, 직무: 클라우드 엔지니어'),
#  '659f4bc3-463d-4bda-86df-7a7839004ced': Document(page_content='회사이름: 프레이, 공고이름: 클라우드 엔지니어 정규직 채용 (네이버클라우드 운영자 우대), url: https://www.jobkorea.co.kr/Recruit/GI_Read/46022827?Oem_Code=C1&logpath=1&stext=%ED%81%B4%EB%9D%BC%EC%9A%B0%EB%93%9C%20%EC%97%94%EC%A7%80%EB%8B%88%EC%96%B4&listno=3, 경력: 신입·경력2년↑, 지역: 서울, 직무: 클라우드 엔지니어'),
#  '168d7a8e-d744-4b74-a601-f788778f0276': Document(page_content='회사이름: ㈜케이비헬스케어, 공고이름: 클라우드 엔지니어 채용, url: https://www.jobkorea.co.kr/Recruit/GI_Read/45914671?Oem_Code=C1&logpath=1&stext=%ED%81%B4%EB%9D%BC%EC%9A%B0%EB%93%9C%20%EC%97%94%EC%A7%80%EB%8B%88%EC%96%B4&listno=4, 경력: 경력3년↑, 지역: 서울, 직무: 클라우드 엔지니어'),
#  'd6597054-7856-42f8-be57-e41a228931da': Document(page_content='회사이름: 마노아이티(ManoIT), 공고이름: [신입] 클라우드 엔지니어 채용 - asap, url: https://www.jobkorea.co.kr/Recruit/GI_Read/45808885?Oem_Code=C1&logpath=1&stext=%ED%81%B4%EB%9D%BC%EC%9A%B0%EB%93%9C%20%EC%97%94%EC%A7%80%EB%8B%88%EC%96%B4&listno=5, 경력: 신입·경력1년↑, 지역: 서울, 직무: 클라우드 엔지니어'),
#  '010802ff-db30-47a0-b05a-82767c517072': Document(page_content='회사이름: 굿어스데이터㈜, 공고이름: naver cloud 엔지니어 (경력 1년 이상 5년 이하) 채용, url: https://www.jobkorea.co.kr/Recruit/GI_Read/46039150?Oem_Code=C1&logpath=1&stext=%ED%81%B4%EB%9D%BC%EC%9A%B0%EB%93%9C%20%EC%97%94%EC%A7%80%EB%8B%88%EC%96%B4&listno=6, 경력: 경력1년↑, 지역: 서울, 직무: 클라우드 엔지니어'),
#  'f1c1b93a-3ed3-4eb0-a213-338a0ea02488': Document(page_content='회사이름: ㈜스타랩스, 공고이름: [스타랩스] aws 클라우드 엔지니어 채용, url: https://www.jobkorea.co.kr/Recruit/GI_Read/45980060?Oem_Code=C1&logpath=1&stext=%ED%81%B4%EB%9D%BC%EC%9A%B0%EB%93%9C%20%EC%97%94%EC%A7%80%EB%8B%88%EC%96%B4&listno=7, 경력: 경력, 지역: 서울, 직무: 클라우드 엔지니어'),
#  'e8ce58f0-2aaf-4297-b00a-7fbdd161dbe9': Document(page_content='회사이름: 주식회사 빗썸, 공고이름: [빗썸] 블록체인 클라우드 엔지니어 (시니어), url: https://www.jobkorea.co.kr/Recruit/GI_Read/45734377?Oem_Code=C1&logpath=1&stext=%ED%81%B4%EB%9D%BC%EC%9A%B0%EB%93%9C%20%EC%97%94%EC%A7%80%EB%8B%88%EC%96%B4&listno=8, 경력: 경력8년↑, 지역: 서울, 직무: 클라우드 엔지니어'),
#  '325c81c5-7fc6-427e-8435-941dcefef867': Document(page_content='회사이름: 주식회사 빗썸, 공고이름: [빗썸] 블록체인 클라우드 엔지니어 (주니어), url: https://www.jobkorea.co.kr/Recruit/GI_Read/45734334?Oem_Code=C1&logpath=1&stext=%ED%81%B4%EB%9D%BC%EC%9A%B0%EB%93%9C%20%EC%97%94%EC%A7%80%EB%8B%88%EC%96%B4&listno=9, 경력: 경력1년↑, 지역: 서울, 직무: 클라우드 엔지니어'),
#  '89edd229-60a9-4963-b5ab-adc1b6ce5f89': Document(page_content='회사이름: ㈜에스티유니타스, 공고이름: [st unitas] 클라우드 엔지니어 팀원급 포지션 인재채용, url: https://www.jobkorea.co.kr/Recruit/GI_Read/45890744?Oem_Code=C1&logpath=1&stext=%ED%81%B4%EB%9D%BC%EC%9A%B0%EB%93%9C%20%EC%97%94%EC%A7%80%EB%8B%88%EC%96%B4&listno=10, 경력: 경력1년↑, 지역: 서울, 직무: 클라우드 엔지니어'),
#  '5cdfe0e2-fc4f-4210-8c59-dab26daa2347': Document(page_content='회사이름: 인프라닉스㈜, 공고이름: (2024년) 클라우드 엔지니어 & 컨설턴트 초빙(신입, 경력사원), url: https://www.jobkorea.co.kr/Recruit/GI_Read/45869330?Oem_Code=C1&logpath=1&stext=%ED%81%B4%EB%9D%BC%EC%9A%B0%EB%93%9C%20%EC%97%94%EC%A7%80%EB%8B%88%EC%96%B4&listno=11, 경력: 신입·경력3년↑, 지역: 서울, 직무: 클라우드 엔지니어'),
#  '3b10b98c-bd2a-481b-9691-3e3dbfd2474c': Document(page_content='회사이름: ㈜에쓰씨케이, 공고이름: cloud 엔지니어, url: https://www.jobkorea.co.kr/Recruit/GI_Read/46054384?Oem_Code=C1&logpath=1&stext=%ED%81%B4%EB%9D%BC%EC%9A%B0%EB%93%9C%20%EC%97%94%EC%A7%80%EB%8B%88%EC%96%B4&listno=12, 경력: 경력3년↑, 지역: 서울, 직무: 클라우드 엔지니어'),
#  'cf44722d-c162-4da7-b36d-33f3d7904574': Document(page_content='회사이름: ㈜스타비젼, 공고이름: [스타비젼] 웹개발, 이커머스 백엔드 개발, 솔루션 개발, 클라우드 엔지니어, url: https://www.jobkorea.co.kr/Recruit/GI_Read/45930247?Oem_Code=C1&logpath=1&stext=%ED%81%B4%EB%9D%BC%EC%9A%B0%EB%93%9C%20%EC%97%94%EC%A7%80%EB%8B%88%EC%96%B4&listno=13, 경력: 경력5년↑, 지역: 서울, 직무: 클라우드 엔지니어'),
#  'e480c735-74c9-4409-a759-211975ff143b': Document(page_content='회사이름: 메가존클라우드㈜, 공고이름: aws managed service (enterprise cloud engineer) 채용, url: https://www.jobkorea.co.kr/Recruit/GI_Read/45772958?Oem_Code=C1&logpath=1&stext=%ED%81%B4%EB%9D%BC%EC%9A%B0%EB%93%9C%20%EC%97%94%EC%A7%80%EB%8B%88%EC%96%B4&listno=14, 경력: 경력무관, 지역: 경기, 직무: 클라우드 엔지니어'),
#  '21316cde-c2ac-46cd-a46e-773fbe6583a9': Document(page_content='회사이름: 메가존소프트, 공고이름: google cloud(engineer,sales) 채용, url: https://www.jobkorea.co.kr/Recruit/GI_Read/45877540?Oem_Code=C1&logpath=1&stext=%ED%81%B4%EB%9D%BC%EC%9A%B0%EB%93%9C%20%EC%97%94%EC%A7%80%EB%8B%88%EC%96%B4&listno=15, 경력: 경력3년↑, 지역: 경기, 직무: 클라우드 엔지니어'),
#  '8a15ddd5-d9fb-40af-a664-29479cea79a5': Document(page_content='회사이름: ㈜에스티씨랩(STCLab.co.,Ltd.), 공고이름: [아기 유니콘] cloud engineer, rust (정규직 전환형 인턴), url: https://www.jobkorea.co.kr/Recruit/GI_Read/46017951?Oem_Code=C1&logpath=1&stext=%ED%81%B4%EB%9D%BC%EC%9A%B0%EB%93%9C%20%EC%97%94%EC%A7%80%EB%8B%88%EC%96%B4&listno=16, 경력: 경력무관, 지역: 서울, 직무: 클라우드 엔지니어'),
# ...
#  '16123b2c-36c2-4ea0-85b4-64e1f738e6b8': Document(page_content='회사이름: (주)트라이큐빅스코리아, 공고이름: 인공지능 시스템 개발자 정규직 채용, url: https://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=search&rec_idx=49352441&location=ts&searchword=%EB%8D%B0%EC%9D%B4%ED%84%B0+%EC%97%94%EC%A7%80%EB%8B%88%EC%96%B4&searchType=search&paid_fl=n&search_uuid=fe89d480-bf94-4592-97ab-e33183851692, 경력: 경력4년↑, 지역: 서울, 직무: 데이터 엔지니어'),
#  'd14af121-ee0b-41a2-929d-f9f50223f28a': Document(page_content='회사이름: (주)토페스, 공고이름: AI/딥러닝 개발자 , url: https://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=search&rec_idx=49527741&location=ts&searchword=%EB%8D%B0%EC%9D%B4%ED%84%B0+%EC%97%94%EC%A7%80%EB%8B%88%EC%96%B4&searchType=search&paid_fl=n&search_uuid=fe89d480-bf94-4592-97ab-e33183851692, 경력: 신입·경력, 지역: 서울, 직무: 데이터 엔지니어'),
#  'ccd91dc7-5b4f-46d9-96ec-c30755e81975': Document(page_content='회사이름: (주)파이오링크, 공고이름: [코스닥 상장사] Linux,Python,Java,Api 개발자 모집(신입/경력), url: https://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=search&rec_idx=49493135&location=ts&searchword=%EB%8D%B0%EC%9D%B4%ED%84%B0+%EC%97%94%EC%A7%80%EB%8B%88%EC%96%B4&searchType=search&paid_fl=n&search_uuid=fe89d480-bf94-4592-97ab-e33183851692, 경력: 신입·경력, 지역: 서울, 직무: 데이터 엔지니어'),
#  'cc38761e-9537-4927-926a-d3fbb3c24fca': Document(page_content='회사이름: (주)댄디테크앤리얼티, 공고이름: 파이썬 개발자 경력직 모집, AI vision 경험자 우대, url: https://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=search&rec_idx=49267107&location=ts&searchword=%EB%8D%B0%EC%9D%B4%ED%84%B0+%EC%97%94%EC%A7%80%EB%8B%88%EC%96%B4&searchType=search&paid_fl=n&search_uuid=fe89d480-bf94-4592-97ab-e33183851692, 경력: 신입, 지역: 서울, 직무: 데이터 엔지니어'),
#  '38ebf4e7-d7bc-4daf-bc6d-327fa704b336': Document(page_content='회사이름: (주)딥브레인에이아이, 공고이름: [딥브레인AI]  Back-End 개발자 채용 (산업기능요원/보충역), url: https://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=search&rec_idx=49455685&location=ts&searchword=%EB%8D%B0%EC%9D%B4%ED%84%B0+%EC%97%94%EC%A7%80%EB%8B%88%EC%96%B4&searchType=search&paid_fl=n&search_uuid=fe89d480-bf94-4592-97ab-e33183851692, 경력: 신입·경력, 지역: 서울, 직무: 데이터 엔지니어'),
#  '4899f776-385e-4b9e-8e75-8fca21e4a851': Document(page_content='회사이름: (주)인딥에이아이, 공고이름: AI채용솔루션 백엔드 개발자 우수인재 모집, url: https://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=search&rec_idx=49533810&location=ts&searchword=%EB%8D%B0%EC%9D%B4%ED%84%B0+%EC%97%94%EC%A7%80%EB%8B%88%EC%96%B4&searchType=search&paid_fl=n&search_uuid=fe89d480-bf94-4592-97ab-e33183851692, 경력: 경력 1~10년, 지역: 서울, 직무: 데이터 엔지니어'),
#  'd8f632c4-d3cc-4762-8d14-f8b3033411c5': Document(page_content='회사이름: 씨드로닉스(주), 공고이름: Back-end(AI데이터플랫폼) 개발자 경력 채용, url: https://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=search&rec_idx=49287229&location=ts&searchword=AI+%EA%B0%9C%EB%B0%9C%EC%9E%90&searchType=search&paid_fl=n&search_uuid=edfb126a-f8a1-4db5-bb51-60267b1feabd, 경력: 경력무관, 지역: 서울, 직무: AI 개발자'),
#  '6da4a742-19ba-4f82-b77b-9fe3fe25ea63': Document(page_content='회사이름: (주)솔트룩스, 공고이름: 인공지능(AI) 솔트룩스 - NLP Research Engineer 신입, url: https://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=search&rec_idx=49459975&location=ts&searchword=AI+%EA%B0%9C%EB%B0%9C%EC%9E%90&searchType=search&paid_fl=n&search_uuid=edfb126a-f8a1-4db5-bb51-60267b1feabd, 경력: 경력 5~10년, 지역: 서울, 직무: AI 개발자'),
#  '5b59d697-045d-46c2-9b82-db821b8a84e8': Document(page_content='회사이름: (주)슈프리마, 공고이름: [슈프라미에이아이] 인공지능/머신러닝 경력직 채용공고, url: https://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=search&rec_idx=49458875&location=ts&searchword=AI+%EA%B0%9C%EB%B0%9C%EC%9E%90&searchType=search&paid_fl=n&search_uuid=edfb126a-f8a1-4db5-bb51-60267b1feabd, 경력: 경력무관, 지역: 서울, 직무: AI 개발자'),
#  'cb862202-1064-4af8-9d03-6d14d26c4424': Document(page_content='회사이름: (주)에이아이스페라, 공고이름: AI Spera [석사병역특례] 개발자 / 엔지니어 부문별 채용, url: https://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=search&rec_idx=49381445&location=ts&searchword=AI+%EA%B0%9C%EB%B0%9C%EC%9E%90&searchType=search&paid_fl=n&search_uuid=edfb126a-f8a1-4db5-bb51-60267b1feabd, 경력: 경력무관, 지역: 서울, 직무: AI 개발자'),
#  '8a07b077-6bab-4efc-b40b-b5731ec5a2f1': Document(page_content='회사이름: (주)서플러스글로벌, 공고이름: AI/ML 연구자, url: https://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=search&rec_idx=49448452&location=ts&searchword=AI+%EA%B0%9C%EB%B0%9C%EC%9E%90&searchType=search&paid_fl=n&search_uuid=edfb126a-f8a1-4db5-bb51-60267b1feabd, 경력: 경력 3~10년, 지역: 경기, 직무: AI 개발자'),
#  '85ae8c45-f0cc-4e93-a3f1-b512d9b5f920': Document(page_content='회사이름: 프라이스원, 공고이름: AI / 딥러닝 개발자, url: https://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=search&rec_idx=49377366&location=ts&searchword=AI+%EA%B0%9C%EB%B0%9C%EC%9E%90&searchType=search&paid_fl=n&search_uuid=edfb126a-f8a1-4db5-bb51-60267b1feabd, 경력: 경력무관, 지역: 서울, 직무: AI 개발자'),
#  '6d26867c-0b6a-464d-885e-8bc601137e8f': Document(page_content='회사이름: (주)마인즈앤컴퍼니, 공고이름: [인공지능솔루션] 엔지니어 직군 채용, url: https://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=search&rec_idx=49361070&location=ts&searchword=AI+%EA%B0%9C%EB%B0%9C%EC%9E%90&searchType=search&paid_fl=n&search_uuid=edfb126a-f8a1-4db5-bb51-60267b1feabd, 경력: 신입·경력, 지역: 경기, 직무: AI 개발자'),
#  '2b04dc65-744a-4238-8b53-b2866266c783': Document(page_content='회사이름: (주)디비엔텍, 공고이름: [병역특례 우대] AI(딥러닝)기반 Object Detection 개발자 모집, url: https://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=search&rec_idx=49395261&location=ts&searchword=AI+%EA%B0%9C%EB%B0%9C%EC%9E%90&searchType=search&paid_fl=n&search_uuid=edfb126a-f8a1-4db5-bb51-60267b1feabd, 경력: 경력 1~3년, 지역: 서울, 직무: AI 개발자'),
#  '6c9f37c1-592e-44d6-81aa-b03a1f998c6c': Document(page_content='회사이름: 메이츠소프트주식회사, 공고이름: 인공지능(AI) S/W개발 팀장급 경력 모집, url: https://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=search&rec_idx=49394122&location=ts&searchword=AI+%EA%B0%9C%EB%B0%9C%EC%9E%90&searchType=search&paid_fl=n&search_uuid=edfb126a-f8a1-4db5-bb51-60267b1feabd, 경력: 경력 1~3년, 지역: 서울, 직무: AI 개발자'),
#  'cfdeb0e2-cb2f-430c-b75e-37ebc35089b6': Document(page_content='회사이름: (주)딥파인, 공고이름: Visual SLAM (vSLAM) 개발자, url: https://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=search&rec_idx=49366228&location=ts&searchword=AI+%EA%B0%9C%EB%B0%9C%EC%9E%90&searchType=search&paid_fl=n&search_uuid=edfb126a-f8a1-4db5-bb51-60267b1feabd, 경력: 경력 3~15년, 지역: 서울, 직무: AI 개발자'),
#  '7351c391-bcde-4281-ad3e-74a8153a3419': Document(page_content='회사이름: (주)델타엑스, 공고이름: AI 연구원 및 개발자 모집, url: https://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=search&rec_idx=49366381&location=ts&searchword=AI+%EA%B0%9C%EB%B0%9C%EC%9E%90&searchType=search&paid_fl=n&search_uuid=edfb126a-f8a1-4db5-bb51-60267b1feabd, 경력: 경력 2~10년, 지역: 서울, 직무: AI 개발자'),
#  '9cb75664-b244-43a9-9a72-2e198c1f3e77': Document(page_content='회사이름: (주)트라이캐치, 공고이름: AI 보이스봇 Voice UX 개발자, url: https://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=search&rec_idx=49429534&location=ts&searchword=AI+%EA%B0%9C%EB%B0%9C%EC%9E%90&searchType=search&paid_fl=n&search_uuid=edfb126a-f8a1-4db5-bb51-60267b1feabd, 경력: 신입·경력, 지역: 경기, 직무: AI 개발자'),
#  'a35c49cd-ae7a-4848-b4db-4218e7362d6a': Document(page_content='회사이름: (주)커넥트웨이브, 공고이름: [커넥트웨이브] AI개발팀 AI 모델러 채용, url: https://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=search&rec_idx=49394713&location=ts&searchword=AI+%EA%B0%9C%EB%B0%9C%EC%9E%90&searchType=search&paid_fl=n&search_uuid=edfb126a-f8a1-4db5-bb51-60267b1feabd, 경력: 경력 2~7년, 지역: 경기, 직무: AI 개발자'),
#  '3b033378-2fe4-40ac-b493-6305cf5b2a16': Document(page_content='회사이름: (주)이노룰스, 공고이름: [AI플랫폼팀] 웹 풀스택 개발자(PL 급) 채용, url: https://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=search&rec_idx=49431193&location=ts&searchword=AI+%EA%B0%9C%EB%B0%9C%EC%9E%90&searchType=search&paid_fl=n&search_uuid=edfb126a-f8a1-4db5-bb51-60267b1feabd, 경력: 경력5년↑, 지역: 경기, 직무: AI 개발자'),
#  '4a8bd69d-5c20-4425-afc9-8292a23598bd': Document(page_content='회사이름: (주)유어라운드, 공고이름: [글로벌 AI SaaS][스타트업] 프론트엔드 웹 개발자 모집, url: https://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=search&rec_idx=49359061&location=ts&searchword=AI+%EA%B0%9C%EB%B0%9C%EC%9E%90&searchType=search&paid_fl=n&search_uuid=edfb126a-f8a1-4db5-bb51-60267b1feabd, 경력: 경력 3~10년, 지역: 경기, 직무: AI 개발자'),
#  '7f927ebc-db7a-4d19-8b3b-383314df0b3e': Document(page_content='회사이름: 주식회사오프리메드, 공고이름: 2024년 (주)오프리메드 AI 개발자 공개채용, url: https://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=search&rec_idx=49236607&location=ts&searchword=AI+%EA%B0%9C%EB%B0%9C%EC%9E%90&searchType=search&paid_fl=n&search_uuid=edfb126a-f8a1-4db5-bb51-60267b1feabd, 경력: 신입·경력, 지역: 서울, 직무: AI 개발자'),
#  'f808c466-32a8-4d25-b07c-9501220ac832': Document(page_content='회사이름: (주)옵트에이아이, 공고이름: 임베디드 AI 개발자 (C++), url: https://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=search&rec_idx=49400874&location=ts&searchword=AI+%EA%B0%9C%EB%B0%9C%EC%9E%90&searchType=search&paid_fl=n&search_uuid=edfb126a-f8a1-4db5-bb51-60267b1feabd, 경력: 경력무관, 지역: 서울, 직무: AI 개발자'),
#  'd1bcc9ea-9b85-4ce2-b601-f14eb97efc94': Document(page_content='회사이름: 디딤365(주), 공고이름: LLM 앱 개발 엔지니어 채용, url: https://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=search&rec_idx=49266609&location=ts&searchword=AI+%EA%B0%9C%EB%B0%9C%EC%9E%90&searchType=search&paid_fl=n&search_uuid=edfb126a-f8a1-4db5-bb51-60267b1feabd, 경력: 경력무관, 지역: 경기, 직무: AI 개발자'),
#  '70a516c0-d155-41a2-9c38-a65320c1076e': Document(page_content='회사이름: (주)미디어윌네트웍스, 공고이름: [알바천국] AI서비스 백엔드 개발자 모집, url: https://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=search&rec_idx=49394863&location=ts&searchword=AI+%EA%B0%9C%EB%B0%9C%EC%9E%90&searchType=search&paid_fl=n&search_uuid=edfb126a-f8a1-4db5-bb51-60267b1feabd, 경력: 경력 2~7년, 지역: 경기, 직무: AI 개발자'),
#  'f637860c-daa5-49a0-b24a-95188c2be986': Document(page_content='회사이름: 주식회사씨에이, 공고이름: AI로봇 스타트업 : AI 개발 인력을 채용합니다, url: https://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=search&rec_idx=49149439&location=ts&searchword=AI+%EA%B0%9C%EB%B0%9C%EC%9E%90&searchType=search&paid_fl=n&search_uuid=edfb126a-f8a1-4db5-bb51-60267b1feabd, 경력: 경력무관, 지역: 서울, 직무: AI 개발자'),
#  '5a41a430-bd1d-4039-9f77-5b3057d23776': Document(page_content='회사이름: (주)덴컴, 공고이름: [음성 AI 기업 덴컴] 프론트엔드 개발자 채용, url: https://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=search&rec_idx=49439912&location=ts&searchword=AI+%EA%B0%9C%EB%B0%9C%EC%9E%90&searchType=search&paid_fl=n&search_uuid=edfb126a-f8a1-4db5-bb51-60267b1feabd, 경력: 경력 7~15년, 지역: 서울, 직무: AI 개발자'),
#  '817d132b-5333-4392-be15-fcfe32f9f23a': Document(page_content='회사이름: (주)포스로직, 공고이름: 이미지 프로세싱 알고리즘 라이브러리(2D,3D,AI 딥러닝) 개발 신입 채용, url: https://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=search&rec_idx=49469289&location=ts&searchword=AI+%EA%B0%9C%EB%B0%9C%EC%9E%90&searchType=search&paid_fl=n&search_uuid=edfb126a-f8a1-4db5-bb51-60267b1feabd, 경력: 경력 2~10년, 지역: 서울, 직무: AI 개발자'),
#  '47e9ebb7-81ef-4565-8dd5-0453cc56d83b': Document(page_content='회사이름: (주)딥노이드, 공고이름: AI연구원 (Computer Vision AI), url: https://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=search&rec_idx=49351369&location=ts&searchword=AI+%EA%B0%9C%EB%B0%9C%EC%9E%90&searchType=search&paid_fl=n&search_uuid=edfb126a-f8a1-4db5-bb51-60267b1feabd, 경력: 경력 3~7년, 지역: 서울, 직무: AI 개발자'),
#  '00ba760c-5d92-4e53-8183-364e204fa6ae': Document(page_content='회사이름: (주)가치소프트, 공고이름: 2D/3D Vision 및 AI SW개발 프로그래머 채용[세종], url: https://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=search&rec_idx=49348141&location=ts&searchword=AI+%EA%B0%9C%EB%B0%9C%EC%9E%90&searchType=search&paid_fl=n&search_uuid=edfb126a-f8a1-4db5-bb51-60267b1feabd, 경력: 경력무관, 지역: 부산, 직무: AI 개발자'),
#  '853d579b-9361-4ff1-a2e3-aada0c4eb222': Document(page_content='회사이름: 주식회사 이지서티, 공고이름: [이지서티] 경력직 솔루션 플랫폼 개발자(JAVA, C 등), url: https://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=search&rec_idx=49420870&location=ts&searchword=AI+%EA%B0%9C%EB%B0%9C%EC%9E%90&searchType=search&paid_fl=n&search_uuid=edfb126a-f8a1-4db5-bb51-60267b1feabd, 경력: 경력무관, 지역: 서울, 직무: AI 개발자'),
#  '1557e21a-daf9-4a9b-ad08-8408f5c705bf': Document(page_content='회사이름: (주)지피티코리아, 공고이름: 생성형AI기반 웹서비스 개발자 채용 - Next.js, React (신입), url: https://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=search&rec_idx=49524058&location=ts&searchword=AI+%EA%B0%9C%EB%B0%9C%EC%9E%90&searchType=search&paid_fl=n&search_uuid=edfb126a-f8a1-4db5-bb51-60267b1feabd, 경력: 신입·경력, 지역: 서울, 직무: AI 개발자'),
#  'dc14542c-d4be-4774-ba80-923a8170a077': Document(page_content='회사이름: 주식회사 몹티콘, 공고이름: 인공지능 영상 인식 SW 개발자 모집 공고, url: https://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=search&rec_idx=49176612&location=ts&searchword=AI+%EA%B0%9C%EB%B0%9C%EC%9E%90&searchType=search&paid_fl=n&search_uuid=edfb126a-f8a1-4db5-bb51-60267b1feabd, 경력: 경력무관, 지역: 경기, 직무: AI 개발자'),
#  '7b604d9b-52e2-452c-97e9-6d221ad53de1': Document(page_content='회사이름: (주)인라이플, 공고이름: [주4.5일] Back end Developer(JAVA) 채용, url: https://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=search&rec_idx=49525680&location=ts&searchword=AI+%EA%B0%9C%EB%B0%9C%EC%9E%90&searchType=search&paid_fl=n&search_uuid=edfb126a-f8a1-4db5-bb51-60267b1feabd, 경력: 경력5년↑, 지역: 서울, 직무: AI 개발자'),
#  'f53c8c19-e1f1-4a43-a658-5eda74d0b365': Document(page_content='회사이름: (주)펨트론, 공고이름: 3D&AI팀 CT알고리즘 개발자, url: https://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=search&rec_idx=49144916&location=ts&searchword=AI+%EA%B0%9C%EB%B0%9C%EC%9E%90&searchType=search&paid_fl=n&search_uuid=edfb126a-f8a1-4db5-bb51-60267b1feabd, 경력: 경력무관, 지역: 서울, 직무: AI 개발자'),
#  '4e783f06-0a4a-472b-b0ff-6810dafe8407': Document(page_content='회사이름: (주)위키드스톰, 공고이름: 연구소 AI팀 개발 팀장급 채용, url: https://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=search&rec_idx=49328435&location=ts&searchword=AI+%EA%B0%9C%EB%B0%9C%EC%9E%90&searchType=search&paid_fl=n&search_uuid=edfb126a-f8a1-4db5-bb51-60267b1feabd, 경력: 경력4년↑, 지역: 경기, 직무: AI 개발자'),
#  'f555623d-1068-4579-982e-d4110b01446a': Document(page_content='회사이름: 브랜드인게이지먼트네트워크인크(영업소), 공고이름: AI 개발자(AI Engineer/Full Stack Developer) 채용, url: https://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=search&rec_idx=49350341&location=ts&searchword=AI+%EA%B0%9C%EB%B0%9C%EC%9E%90&searchType=search&paid_fl=n&search_uuid=edfb126a-f8a1-4db5-bb51-60267b1feabd, 경력: 경력2년↑, 지역: 서울, 직무: AI 개발자'),
#  '38349568-bb7e-4fb7-89e7-a0c5d99ee793': Document(page_content='회사이름: 다임리서치(주), 공고이름: AI 솔루션 Unity 3D 시니어 개발자, url: https://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=search&rec_idx=49408573&location=ts&searchword=AI+%EA%B0%9C%EB%B0%9C%EC%9E%90&searchType=search&paid_fl=n&search_uuid=edfb126a-f8a1-4db5-bb51-60267b1feabd, 경력: 경력2년↑, 지역: 경기, 직무: AI 개발자'),
#  '772195e4-4fb3-4989-a256-6bfd60d6d08f': Document(page_content='회사이름: (주)로민, 공고이름: 멀티모달 AI 엔지니어 채용, url: https://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=search&rec_idx=49361620&location=ts&searchword=AI+%EA%B0%9C%EB%B0%9C%EC%9E%90&searchType=search&paid_fl=n&search_uuid=edfb126a-f8a1-4db5-bb51-60267b1feabd, 경력: 경력 3~20년, 지역: 서울, 직무: AI 개발자'),
#  '1d437466-e9f1-47a5-a0fe-7f4fa744525a': Document(page_content='회사이름: (주)옵트에이아이, 공고이름: 임베디드 AI 개발자 (C++) (병역특례), url: https://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=search&rec_idx=49308082&location=ts&searchword=AI+%EA%B0%9C%EB%B0%9C%EC%9E%90&searchType=search&paid_fl=n&search_uuid=edfb126a-f8a1-4db5-bb51-60267b1feabd, 경력: 경력무관, 지역: 서울, 직무: AI 개발자'),
#  '8047b082-1015-49d7-9782-499892f9e0f3': Document(page_content='회사이름: (주)네오위즈, 공고이름: [네오위즈] AI 연구원 - 데이터 분석 (전문연구요원), url: https://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=search&rec_idx=49512819&location=ts&searchword=AI+%EA%B0%9C%EB%B0%9C%EC%9E%90&searchType=search&paid_fl=n&search_uuid=edfb126a-f8a1-4db5-bb51-60267b1feabd, 경력: 경력무관, 지역: 서울, 직무: AI 개발자'),
#  'da519f00-4020-4682-bbd9-68d1201458a5': Document(page_content='회사이름: (주)크라우드웍스, 공고이름: [크라우드웍스] 병특/전문연전형) 서비스개발실 백엔드개발자, url: https://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=search&rec_idx=49530752&location=ts&searchword=AI+%EA%B0%9C%EB%B0%9C%EC%9E%90&searchType=search&paid_fl=n&search_uuid=edfb126a-f8a1-4db5-bb51-60267b1feabd, 경력: 신입, 지역: 경북, 직무: AI 개발자'),
#  ...}

# %%
retriever = db.as_retriever()

# %%
def get_user_input():
    job = input('원하시는 직무를 입력하세요.')
    exp = input('신입 / 경력 중 해당하는 내용을 입력하세요.')
    loc = input('원하시는 지역을 입력하세요.')
    return job, exp, loc

# %%
from langchain_core.output_parsers import StrOutputParser
from langchain_core.runnables import RunnablePassthrough, RunnableLambda
from langchain_core.prompts import PromptTemplate, ChatPromptTemplate, MessagesPlaceholder
from langchain_openai import ChatOpenAI
from langchain.memory import ConversationBufferMemory
from langchain.chains import LLMChain, ConversationChain

system_message = """
    너는 입력된 quesetion 속에 포함된 직무, 경력, 선호 지역에 맞는 채용 공고를 다섯 개씩 출력하는 탐색 AI야.
    검색된 context들 중 입력된 직무와 같은 카테고리인 채용 공고를 찾아오면 돼.
    공고이름에 직무가 들어가는 공고를 우선으로 출력하고, 그 이외에는 랜덤으로 출력해줘.
    만약 사용자가 더 많은 공고를 필요로 한다면, 같은 카테고리에서 이전에 네가 가져온 공고들을 제외하고 나머지 공고들 중 다섯 개를 뽑아서 가져와서 출력해줘.
    출력 형식은 하나의 공고마다 회사이름, 공고이름, url를 출력해주면 돼.

    # context: {context}
"""

prompt = ChatPromptTemplate.from_messages([
    ('system', system_message),
    MessagesPlaceholder(variable_name='chat_history'),
    ('human', '{question}'),
])

# %%
llm = ChatOpenAI(model='gpt-4o-mini', temperature=0.1)

# %%
memory = ConversationBufferMemory(memory_key='chat_history', return_messages=True)

# %%
def load_memory(input):
    print(input)
    return memory.load_memory_variables({})['chat_history']

# %%
def chatbot():
    # 사용자 입력 받기
    # job, exp, loc = get_user_input()
    # query = f'직무: {job}, 경력: {exp}, 지역: {loc}'

    question = input('질문을 입력하세요.')
    results = retriever.get_relevant_documents(question)

    # 검색된 결과들로 context 구성
    context = "\n".join([result.page_content for result in results])

    # 질문 생성
    # question = f'{loc}에서 {exp}을 채용하는 {job} 공고 알려줘'

    # 파이프라인 구성
    chain = (
        RunnablePassthrough.assign(context=RunnableLambda(lambda _: context))
        | RunnablePassthrough.assign(chat_history=load_memory)
        | prompt
        | llm
        | StrOutputParser()
    )

    # 실행 및 응답 얻기
    response = chain.invoke({'question': question})

    # 메모리에 대화 기록 저장
    memory.save_context(
        {'input': question},
        {'output': response},
    )

    # 결과 출력
    print(response)

# %%
while True:
    chatbot()
    memory.load_memory_variables({})
# Out:
# {'question': '서울에서 신입을 채용하는 데이터 분석 공고 알려줘', 'context': '회사이름: (주)부동산플래닛, 공고이름: [데이터분석가] Data Analyst, url: https://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=search&rec_idx=49353549&location=ts&searchword=%EB%8D%B0%EC%9D%B4%ED%84%B0+%EB%B6%84%EC%84%9D%EA%B0%80&searchType=search&paid_fl=n&search_uuid=8b0e40cc-6749-4a26-938a-a0fc1630228a, 경력: 경력 1~10년, 지역: 서울, 직무: 데이터 분석가\n회사이름: (주)사람인, 공고이름: [사람인] AI 서비스 개발(석사 신입 지원 가능), url: https://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=search&rec_idx=49530850&location=ts&searchword=%EB%8D%B0%EC%9D%B4%ED%84%B0+%EB%B6%84%EC%84%9D%EA%B0%80&searchType=search&paid_fl=n&search_uuid=8b0e40cc-6749-4a26-938a-a0fc1630228a, 경력: 신입·경력, 지역: 서울, 직무: 데이터 분석가\n회사이름: (주)부동산플래닛, 공고이름: [데이터분석가] Data Analyst 채용, url: https://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=search&rec_idx=49473967&location=ts&searchword=%EB%8D%B0%EC%9D%B4%ED%84%B0+%EB%B6%84%EC%84%9D%EA%B0%80&searchType=search&paid_fl=n&search_uuid=9bc6b832-bca0-4d29-aae0-6f778a3a89f5, 경력: 신입·경력, 지역: 서울, 직무: 데이터 분석가\n회사이름: (주)사람인, 공고이름: [사람인] 데이터 엔지니어 (전환형인턴), url: https://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=search&rec_idx=49394068&location=ts&searchword=%EB%8D%B0%EC%9D%B4%ED%84%B0+%EB%B6%84%EC%84%9D%EA%B0%80&searchType=search&paid_fl=n&search_uuid=d24d5c57-86b5-4018-a035-423ed253248a, 경력: 경력3년↑, 지역: 서울, 직무: 데이터 분석가'}
# 다음은 서울에서 신입을 채용하는 데이터 분석 관련 공고입니다:
#
# 1. 회사이름: (주)사람인
#    공고이름: [사람인] AI 서비스 개발(석사 신입 지원 가능)
#    url: [링크](https://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=search&rec_idx=49530850&location=ts&searchword=%EB%8D%B0%EC%9D%B4%ED%84%B0+%EB%B6%84%EC%84%9D%EA%B0%80&searchType=search&paid_fl=n&search_uuid=8b0e40cc-6749-4a26-938a-a0fc1630228a)
#
# 2. 회사이름: (주)부동산플래닛
#    공고이름: [데이터분석가] Data Analyst 채용
#    url: [링크](https://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=search&rec_idx=49473967&location=ts&searchword=%EB%8D%B0%EC%9D%B4%ED%84%B0+%EB%B6%84%EC%84%9D%EA%B0%80&searchType=search&paid_fl=n&search_uuid=9bc6b832-bca0-4d29-aae0-6f778a3a89f5)
#
# 3. 회사이름: (주)부동산플래닛
#    공고이름: [데이터분석가] Data Analyst
#    url: [링크](https://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=search&rec_idx=49353549&location=ts&searchword=%EB%8D%B0%EC%9D%B4%ED%84%B0+%EB%B6%84%EC%84%9D%EA%B0%80&searchType=search&paid_fl=n&search_uuid=8b0e40cc-6749-4a26-938a-a0fc1630228a)
#
# 4. 회사이름: (주)사람인
#    공고이름: [사람인] 데이터 엔지니어 (전환형인턴)
#    url: [링크](https://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=search&rec_idx=49394068&location=ts&searchword=%EB%8D%B0%EC%9D%B4%ED%84%B0+%EB%B6%84%EC%84%9D%EA%B0%80&searchType=search&paid_fl=n&search_uuid=d24d5c57-86b5-4018-a035-423ed253248a)
#
# 5. 회사이름: (주)부동산플래닛
#    공고이름: [데이터분석가] Data Analyst (신입)
#    url: [링크](https://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=search&rec_idx=49473967&location=ts&searchword=%EB%8D%B0%EC%9D%B4%ED%84%B0+%EB%B6%84%EC%84%9D%EA%B0%80&searchType=search&paid_fl=n&search_uuid=9bc6b832-bca0-4d29-aae0-6f778a3a89f5)
#
# 위의 공고들을 확인해보세요! 추가로 더 필요하시면 말씀해 주세요.
# {'question': '에서 을 채용하는 혹시 더 알려줄 수 있어? 공고 알려줘', 'context': '회사이름: ㈜알지티, 공고이름: window application 개발자 채용, url: https://www.jobkorea.co.kr/Recruit/GI_Read/46041113?Oem_Code=C1&logpath=1&stext=API%20%EA%B0%9C%EB%B0%9C%EC%9E%90&listno=49, 경력: 경력3년↑, 지역: 서울, 직무: API 개발자\n회사이름: ㈜알라딘커뮤니케이션, 공고이름: ai 엔지니어 개발자, url: https://www.jobkorea.co.kr/Recruit/GI_Read/45962660?Oem_Code=C1&logpath=1&stext=AI%20%EA%B0%9C%EB%B0%9C%EC%9E%90&listno=55, 경력: 경력5년↑, 지역: 서울, 직무: AI 개발자\n회사이름: 숲(SOOP), 공고이름: AI 엔지니어 리더, url: https://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=search&rec_idx=49391186&location=ts&searchword=%EB%A8%B8%EC%8B%A0%EB%9F%AC%EB%8B%9D+%EC%97%94%EC%A7%80%EB%8B%88%EC%96%B4&searchType=search&paid_fl=n&search_uuid=483a3df3-5f6b-4336-ae36-9a14405ccc7f, 경력: 경력1년↑, 지역: 경기, 직무: 머신러닝 엔지니어\n회사이름: ㈜라이앤캐처스, 공고이름: [경력직] 추천엔지니어(ml엔지니어) 모집, url: https://www.jobkorea.co.kr/Recruit/GI_Read/45913134?Oem_Code=C1&logpath=1&stext=%EB%A8%B8%EC%8B%A0%EB%9F%AC%EB%8B%9D%20%EC%97%94%EC%A7%80%EB%8B%88%EC%96%B4&listno=6, 경력: 경력3년↑, 지역: 서울, 직무: 머신러닝 엔지니어'}

# %%
import random
import re

retriever = db.as_retriever(search_kwargs={'k': 50})

# 저장된 출력 공고 목록을 추적할 변수
output_history = []
user_input_data = {}  # 사용자 입력을 저장할 변수

def get_user_input():
    job = input('원하시는 직무를 입력하세요: ')
    exp = input('신입 / 경력 중 해당하는 내용을 입력하세요: ')
    loc = input('원하시는 지역을 입력하세요: ')
    return job, exp, loc

from langchain_core.output_parsers import StrOutputParser
from langchain_core.runnables import RunnablePassthrough, RunnableLambda
from langchain_core.prompts import ChatPromptTemplate, MessagesPlaceholder
from langchain_openai import ChatOpenAI
from langchain.memory import ConversationBufferMemory
from langchain.chains import LLMChain, ConversationChain

system_message = """
    너는 입력된 quesetion 속에 포함된 직무, 경력, 선호 지역에 맞는 채용 공고를 다섯 개씩 출력하는 탐색 AI야.
    검색된 context들 중 입력된 직무와 같은 카테고리인 채용 공고를 찾아오면 돼.
    공고이름에 직무가 들어가는 공고를 우선으로 출력하고, 그 이외에는 랜덤으로 출력해줘.
    만약 사용자가 더 많은 공고를 필요로 한다면, 같은 카테고리에서 이전에 네가 가져온 공고들을 제외하고 나머지 공고들 중 다섯 개를 뽑아서 가져와서 출력해줘.
    출력 형식은 하나의 공고마다 회사이름, 공고이름, url를 출력해주면 돼.

    # context: {context}
"""

prompt = ChatPromptTemplate.from_messages([
    ('system', system_message),
    MessagesPlaceholder(variable_name='chat_history'),
    ('human', '{question}'),
])
llm = ChatOpenAI(model='gpt-4o-mini', temperature=0.1)
memory = ConversationBufferMemory(memory_key='chat_history', return_messages=True)

def load_memory(input):
    return memory.load_memory_variables({})['chat_history']

def extract_company_and_title(page_content):
    company_pattern = r"회사이름: ([^,]+)"
    job_title_pattern = r"공고이름: ([^,]+)"
    url_pattern = r"url: ([^ ]+)"
    
    company_name = re.search(company_pattern, page_content)
    job_title = re.search(job_title_pattern, page_content)
    url = re.search(url_pattern, page_content)
    
    return company_name.group(1) if company_name else None, job_title.group(1) if job_title else None, url.group(1) if url else None

def prioritize_job_title(results, job):
    job_related = []
    non_job_related = []
    
    for result in results:
        company_name, job_title, url = extract_company_and_title(result.page_content)
        
        if job_title and job.lower() in job_title.lower():
            job_related.append(result)
        else:
            non_job_related.append(result)
    
    return job_related + random.sample(non_job_related, min(5, len(non_job_related)))

def chatbot():
    global user_input_data  # 사용자 입력 데이터를 전역 변수로 사용
    if not user_input_data:
        # 사용자로부터 직무, 경력, 지역 입력 받기 (처음 한 번만)
        job, exp, loc = get_user_input()
        user_input_data = {"job": job, "exp": exp, "loc": loc}
    else:
        # 이미 입력된 데이터 사용
        job = user_input_data["job"]
        exp = user_input_data["exp"]
        loc = user_input_data["loc"]
    
    question = f'{loc}에서 {exp}을 채용하는 {job} 공고 알려줘'
    
    # retriever에서 더 많은 결과를 가져오도록 설정 (예: 10개)
    results = retriever.get_relevant_documents(question, limit=10)
    
    # 직무가 제목에 포함된 공고를 우선적으로 가져오기
    results = prioritize_job_title(results, job)
    
    global output_history
    if output_history:
        # 이전에 출력된 결과는 제외하고 새로운 공고만 출력
        results = [result for result in results if result not in output_history]
    
    output = results[:5]  # 새로운 공고 중에서 5개 출력
    output_history.extend(output)  # 출력된 공고를 기록
    
    # 결과 출력
    for result in output:
        company_name, job_title, url = extract_company_and_title(result.page_content)
        print(f"회사이름: {company_name}, 공고이름: {job_title}, URL: {url}")
    
    memory.save_context({'input': question}, {'output': [f"회사이름: {company_name}, 공고이름: {job_title}, URL: {url}" for result in output]})
    
    # 더보기 여부 처리
    more_query = input("더 보기를 원하시면 'yes'를 입력하세요.")
    if more_query.lower() == 'yes':
        chatbot()  # 사용자 입력 없이 더보기 결과를 출력

# 챗봇 실행
chatbot()
# Out:
# 회사이름: (주)한국정보통계, 공고이름: [통계팀] 데이터 분석가(사회조사분석사), URL: https://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=search&rec_idx=49473967&location=ts&searchword=%EB%8D%B0%EC%9D%B4%ED%84%B0+%EB%B6%84%EC%84%9D%EA%B0%80&searchType=search&paid_fl=n&search_uuid=9bc6b832-bca0-4d29-aae0-6f778a3a89f5,
# 회사이름: (사)한국컨설팅산업협회, 공고이름: 데이터 분석 부문 컨설턴트 채용, URL: https://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=search&rec_idx=49475791&location=ts&searchword=%EB%8D%B0%EC%9D%B4%ED%84%B0+%EB%B6%84%EC%84%9D%EA%B0%80&searchType=search&paid_fl=n&search_uuid=9bc6b832-bca0-4d29-aae0-6f778a3a89f5,
# 회사이름: ㈜토마토시스템, 공고이름: [(주)토마토시스템] ai데이터 분석 부문 채용(신입/경력), URL: https://www.jobkorea.co.kr/Recruit/GI_Read/45999830?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D&listno=19,
# 회사이름: ㈜에이브랩스, 공고이름: 데이터 분석 (data scientist) 채용, URL: https://www.jobkorea.co.kr/Recruit/GI_Read/46057474?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D&listno=41,
# 회사이름: 더플랜비랩, 공고이름: 데이터 분석 및 추출 가공 신입/경력 채용, URL: https://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=search&rec_idx=49322429&location=ts&searchword=%EB%8D%B0%EC%9D%B4%ED%84%B0+%EB%B6%84%EC%84%9D%EA%B0%80&searchType=search&paid_fl=n&search_uuid=9bc6b832-bca0-4d29-aae0-6f778a3a89f5,
# 회사이름: (사)한국기술사업화진흥협회, 공고이름: [무료교육] 제조기업 기반 빅데이터 분석 실무, URL: https://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=search&rec_idx=49487327&location=ts&searchword=%EB%8D%B0%EC%9D%B4%ED%84%B0+%EB%B6%84%EC%84%9D%EA%B0%80&searchType=search&paid_fl=n&search_uuid=d24d5c57-86b5-4018-a035-423ed253248a,
# 회사이름: ㈜네피리티, 공고이름: [서울] 데이터 분석 및 ai모델 개발 정규직/계약직 모집, URL: https://www.jobkorea.co.kr/Recruit/GI_Read/45911857?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D&listno=34,
# 회사이름: 콘센트릭스서비스코리아(유), 공고이름: ga/aa 데이터 분석, URL: https://www.jobkorea.co.kr/Recruit/GI_Read/46028449?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D&listno=7,
# 회사이름: (주)시스노바, 공고이름: [SYSNOVA]데이터 분석 및 AI 모델 개발 연구원, URL: https://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=search&rec_idx=49534693&location=ts&searchword=%EB%8D%B0%EC%9D%B4%ED%84%B0+%EB%B6%84%EC%84%9D%EA%B0%80&searchType=search&paid_fl=n&search_uuid=9bc6b832-bca0-4d29-aae0-6f778a3a89f5,
# 회사이름: (주)데이터누리, 공고이름: [데이터누리] 데이터 분석가를 모십니다., URL: https://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=search&rec_idx=49257728&location=ts&searchword=%EB%8D%B0%EC%9D%B4%ED%84%B0+%EB%B6%84%EC%84%9D%EA%B0%80&searchType=search&paid_fl=n&search_uuid=9bc6b832-bca0-4d29-aae0-6f778a3a89f5,
# 회사이름: 호전실업(주), 공고이름: 데이터 분석, URL: https://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=search&rec_idx=49528482&location=ts&searchword=%EB%8D%B0%EC%9D%B4%ED%84%B0+%EB%B6%84%EC%84%9D%EA%B0%80&searchType=search&paid_fl=n&search_uuid=9bc6b832-bca0-4d29-aae0-6f778a3a89f5,
# 회사이름: (주)온택트헬스, 공고이름: 데이터 분석가 채용, URL: https://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=search&rec_idx=49332193&location=ts&searchword=%EB%8D%B0%EC%9D%B4%ED%84%B0+%EB%B6%84%EC%84%9D%EA%B0%80&searchType=search&paid_fl=n&search_uuid=9bc6b832-bca0-4d29-aae0-6f778a3a89f5,
# 회사이름: 더스윙, 공고이름: 데이터 분석가(Data Analyst), URL: https://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=search&rec_idx=49373361&location=ts&searchword=%EB%8D%B0%EC%9D%B4%ED%84%B0+%EC%82%AC%EC%9D%B4%EC%96%B8%ED%8B%B0%EC%8A%A4%ED%8A%B8&searchType=search&paid_fl=n&search_uuid=f4fa7d9f-ddae-494d-a361-edc2d6aa7000,
# 회사이름: 주식회사 빗썸, 공고이름: [빗썸] 데이터 분석 (인턴), URL: https://www.jobkorea.co.kr/Recruit/GI_Read/45974468?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D&listno=16,
# 회사이름: ㈜인라이플, 공고이름: [주4.5일근무] 데이터 분석 및 기획자 채용, URL: https://www.jobkorea.co.kr/Recruit/GI_Read/45711948?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D&listno=1,
